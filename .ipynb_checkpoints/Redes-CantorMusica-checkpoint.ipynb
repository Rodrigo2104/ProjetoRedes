# %%
from statistics import mean
import seaborn as sns
import networkx as nx
import pandas as pd
import time
import datetime
import freeman as fm
import operator
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import scipy
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Carregamento das bases de dados

# %%
data = pd.read_csv('bill/hotStuff.csv')

# %%
data2 = pd.read_excel('bill/hot100.xlsx')

# %%
data2.columns
# Out:
# Index(['SongID', 'Performer', 'Song', 'spotify_genre', 'spotify_track_id',
#        'spotify_track_preview_url', 'spotify_track_album',
#        'spotify_track_explicit', 'spotify_track_duration_ms',
#        'spotify_track_popularity', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
def filtro(musica):
    new = musica.replace("#","")
    new = new.replace('"',"")
    new = new.replace("'","")
    new=new.replace("(","")
    new=new.replace(")","")
    new=new.replace("[","")
    new=new.replace("]","")
    new=new.replace("ç","c")
    new=new.replace("é","e")
    new=new.replace("ñ","n")
    new=new.replace("ò","o")
    new=new.replace("¿","?")
    new=new.replace("ó","o")
    new=new.replace("á","a")
    new=new.replace("ö","o")
    new=new.replace("Ó","O")
    new=new.replace("à","a")
    new=new.replace("�","?")
    
    
    return new

# %%
def sum100(number):
    return 100-number

# %%
def inv(number):
    return 1/number

# %%
def log(number):
    return np.log(number)

# %%
def loginv(number):
    return (1/(np.log(number)+1))

# %%
dic_func={sum100:"sum100",
          inv:"inv",
          log:"log",
          loginv:"loginv"}

# %%
l_drop=['danceability',
       'energy', 'key', 'loudness', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness']

# %%
def variaveis(dataf, year):
    dataframe=dataf[year].copy()
    
    def go_to_apply (dici,row):
        return dici[row['SongID']]

    for i in dic_func:
        name=dic_func[i]
        func=i
        dic={}
        for i in dataframe.index:
            print(dataframe["SongID"][i])
            if (dataframe["SongID"][i]) in dic:
                print("foi")
                dic[dataframe["SongID"][i]] += func(dataframe["Week Position"][i])
            else:
                print("nao")
                dic[dataframe["SongID"][i]] = func(dataframe["Week Position"][i])
        
        dataframe[name] = dataframe.apply (lambda row: go_to_apply(dic, row), axis=1)
    print(dataframe.columns)
        
    dataframe.drop_duplicates(subset="SongID", keep="last", inplace=True)
    
    dataframe=dataframe.reset_index(drop=True)
    return dataframe

# %%
# for i in dic_func:
#     variaveis(i,dic_func[i])    USAR DEPOIS

# %%
def diats(row):
    return pd.Timestamp(row["WeekID"])

# %%
data['timestamp']=data.apply (lambda row: diats(row), axis=1)

# %%
def musica_filtrada (row):
   return filtro(row['SongID'])

# %%
data2['SongFiltred']=data2.apply (lambda row: musica_filtrada(row), axis=1)

# %%
data.columns
# Out:
# Index(['url', 'WeekID', 'Week Position', 'Song', 'Performer', 'SongID',
#        'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart',
#        'timestamp'],
#       dtype='object')

# %%
dic_anos={}
for ano in range(2000,2020):
    v1="1/1/{0}".format(ano)
    v2 = "1/1/{0}".format(ano+1)
    dic_anos[ano]=[v1,v2]
    
print(dic_anos)
# Out:
# {2000: ['1/1/2000', '1/1/2001'], 2001: ['1/1/2001', '1/1/2002'], 2002: ['1/1/2002', '1/1/2003'], 2003: ['1/1/2003', '1/1/2004'], 2004: ['1/1/2004', '1/1/2005'], 2005: ['1/1/2005', '1/1/2006'], 2006: ['1/1/2006', '1/1/2007'], 2007: ['1/1/2007', '1/1/2008'], 2008: ['1/1/2008', '1/1/2009'], 2009: ['1/1/2009', '1/1/2010'], 2010: ['1/1/2010', '1/1/2011'], 2011: ['1/1/2011', '1/1/2012'], 2012: ['1/1/2012', '1/1/2013'], 2013: ['1/1/2013', '1/1/2014'], 2014: ['1/1/2014', '1/1/2015'], 2015: ['1/1/2015', '1/1/2016'], 2016: ['1/1/2016', '1/1/2017'], 2017: ['1/1/2017', '1/1/2018'], 2018: ['1/1/2018', '1/1/2019'], 2019: ['1/1/2019', '1/1/2020']}

# %%
data.tail()
# Out:
#                                                       url      WeekID  \
# 320490  https://www.billboard.com/charts/hot-100/2019-...    1/5/2019
# 320491  https://www.billboard.com/charts/hot-100/2019-...   12/7/2019
# 320492  https://www.billboard.com/charts/hot-100/2019-...  12/14/2019
# 320493  https://www.billboard.com/charts/hot-100/2019-...  12/21/2019
# 320494  https://www.billboard.com/charts/hot-100/2019-...  12/28/2019
#
#         Week Position              Song    Performer  \
# 320490              8  Jingle Bell Rock  Bobby Helms
# 320491             47  Jingle Bell Rock  Bobby Helms
# 320492             23  Jingle Bell Rock  Bobby Helms
# 320493             15  Jingle Bell Rock  Bobby Helms
# 320494              9  Jingle Bell Rock  Bobby Helms
#
#                              SongID  Instance  Previous Week Position  \
# 320490  Jingle Bell RockBobby Helms         7                    13.0
# 320491  Jingle Bell RockBobby Helms         8                     NaN
# 320492  Jingle Bell RockBobby Helms         8                    47.0
# 320493  Jingle Bell RockBobby Helms         8                    23.0
# 320494  Jingle Bell RockBobby Helms         8                    15.0
#
#         Peak Position  Weeks on Chart  timestamp
# 320490              8              25 2019-01-05
# 320491             47              26 2019-12-07
# 320492             23              27 2019-12-14
# 320493             15              28 2019-12-21
# 320494              9              29 2019-12-28

# %%
datamerge = pd.merge(data,data2,on='SongID')
l_drop=['danceability',
       'energy', 'key', 'loudness', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness','spotify_genre']

for i in l_drop:
    dl=datamerge.dropna(axis=0, how="all", subset=[i], inplace=False)
    datamerge=dl
datah=datamerge.copy()
indexNames = datah[datah["spotify_genre"] == "[]" ].index
datah.drop(indexNames , inplace=True, axis=0)
dataframe=datah
dataframe.drop_duplicates(subset='SongID', keep='first', inplace=True)
dataframe=dataframe.reset_index(drop=True)

# %%
dic_dataframe={}
for i in (dic_anos):
    dic_dataframe[i] = dataframe[(dataframe["timestamp"]>=pd.Timestamp(dic_anos[i][0])) & (dataframe["timestamp"]<=pd.Timestamp(dic_anos[i][1]))]

# %%
dataframe
# Out:
#                                                      url     WeekID  \
# 0      https://www.billboard.com/charts/hot-100/2019-...   2/2/2019
# 1      https://www.billboard.com/charts/hot-100/2019-...  3/16/2019
# 2      https://www.billboard.com/charts/hot-100/2019-...  2/23/2019
# 3      https://www.billboard.com/charts/hot-100/2019-...   7/6/2019
# 4      https://www.billboard.com/charts/hot-100/2018-...  8/18/2018
# ...                                                  ...        ...
# 22015  http://www.billboard.com/charts/hot-100/2000-0...   6/3/2000
# 22016  http://www.billboard.com/charts/hot-100/1972-0...   4/8/1972
# 22017  http://www.billboard.com/charts/hot-100/1999-0...   4/3/1999
# 22018  http://www.billboard.com/charts/hot-100/2005-0...  2/26/2005
# 22019  http://www.billboard.com/charts/hot-100/1962-0...  7/14/1962
#
#        Week Position                                    Song_x  \
# 0                  1                                   7 Rings
# 1                  1                                    Sucker
# 2                  2  Break Up With Your Girlfriend, I'm Bored
# 3                  2                                  Senorita
# 4                  4                                Sicko Mode
# ...              ...                                       ...
# 22015             71                             What'Chu Like
# 22016             83                              What'd I Say
# 22017             98                 What'd You Come Here For?
# 22018            100                     What's A Guy Gotta Do
# 22019             88  What's A Matter Baby (Is It Hurting You)
#
#                          Performer_x  \
# 0                      Ariana Grande
# 1                     Jonas Brothers
# 2                      Ariana Grande
# 3      Shawn Mendes & Camila Cabello
# 4                       Travis Scott
# ...                              ...
# 22015       Da Brat Featuring Tyrese
# 22016                     Rare Earth
# 22017                 Trina & Tamara
# 22018                    Joe Nichols
# 22019                      Timi Yuro
#
#                                                   SongID  Instance  \
# 0                                   7 RingsAriana Grande         1
# 1                                   SuckerJonas Brothers         1
# 2      Break Up With Your Girlfriend, I'm BoredAriana...         1
# 3                  SenoritaShawn Mendes & Camila Cabello         1
# 4                                 Sicko ModeTravis Scott         1
# ...                                                  ...       ...
# 22015              What'Chu LikeDa Brat Featuring Tyrese         1
# 22016                             What'd I SayRare Earth         1
# 22017            What'd You Come Here For?Trina & Tamara         1
# 22018                   What's A Guy Gotta DoJoe Nichols         1
# 22019  What's A Matter Baby (Is It Hurting You)Timi Yuro         1
#
#        Previous Week Position  Peak Position  Weeks on Chart  ... loudness  \
# 0                         NaN              1               1  ...  -10.732
# 1                         NaN              1               1  ...   -5.065
# 2                         NaN              2               1  ...   -5.290
# 3                         NaN              2               1  ...   -6.039
# 4                         NaN              4               1  ...   -3.714
# ...                       ...            ...             ...  ...      ...
# 22015                     NaN             71               1  ...   -8.951
# 22016                     NaN             83               1  ...   -8.682
# 22017                     NaN             98               1  ...   -3.643
# 22018                     NaN            100               1  ...   -3.808
# 22019                     NaN             88               1  ...   -9.354
#
#       mode speechiness acousticness instrumentalness liveness valence  \
# 0      0.0      0.3340      0.59200         0.000000   0.0881   0.327
# 1      0.0      0.0588      0.04270         0.000000   0.1060   0.952
# 2      0.0      0.0917      0.04210         0.000000   0.1060   0.335
# 3      0.0      0.0287      0.03700         0.000000   0.0945   0.750
# 4      1.0      0.2220      0.00513         0.000000   0.1240   0.446
# ...    ...         ...          ...              ...      ...     ...
# 22015  0.0      0.2400      0.01700         0.000000   0.0669   0.817
# 22016  1.0      0.2090      0.25300         0.001610   0.3160   0.750
# 22017  1.0      0.0719      0.05080         0.001230   0.0580   0.759
# 22018  1.0      0.0770      0.66200         0.000031   0.0746   0.920
# 22019  1.0      0.0430      0.43000         0.000000   0.0704   0.895
#
#          tempo  time_signature  \
# 0      140.048             4.0
# 1      137.958             4.0
# 2      169.999             4.0
# 3      116.947             4.0
# 4      155.008             4.0
# ...        ...             ...
# 22015   99.974             4.0
# 22016  182.397             4.0
# 22017  102.907             4.0
# 22018  170.224             4.0
# 22019  113.569             4.0
#
#                                              SongFiltred
# 0                                   7 RingsAriana Grande
# 1                                   SuckerJonas Brothers
# 2      Break Up With Your Girlfriend, Im BoredAriana ...
# 3                  SenoritaShawn Mendes & Camila Cabello
# 4                                 Sicko ModeTravis Scott
# ...                                                  ...
# 22015               WhatChu LikeDa Brat Featuring Tyrese
# 22016                              Whatd I SayRare Earth
# 22017             Whatd You Come Here For?Trina & Tamara
# 22018                    Whats A Guy Gotta DoJoe Nichols
# 22019     Whats A Matter Baby Is It Hurting YouTimi Yuro
#
# [22020 rows x 33 columns]

# %% [markdown]
# Função para checar se a string está na tabela ascii

# %% [markdown]
# Filtro aplicado no songid

# %% [markdown]
# Dicionário dos SongIDs e as respectivas semanas na Bilboard

# %% [markdown]
# Filtro aplicado no nome das músicas

# %%
import re

dic_bugs={
    "Lil Nas &":"Lil Nas X",
    "& Ambassadors":"X Ambassadors",
    "Mia &":"Mia X",
    "for KING & COUNTRY":"for KING and COUNTRY",
    "Brooks & Dunn":"Brooks and Dunn"   
}

feat="Featuring"
def parse(nomes):
    
    new_nomes=nomes.replace("(","")
    new_nomes=new_nomes.replace(")","")
    new_nomes=new_nomes.replace("[","")
    new_nomes=new_nomes.replace("]","")
    new_nomes=new_nomes.replace("'","")
    new_nomes=new_nomes.replace('"',"")
    new_nomes=new_nomes.replace(", "," & ")
    new_nomes=new_nomes.replace("Featuring","&")
    new_nomes=new_nomes.replace("Feat.","&")
    new_nomes=new_nomes.replace(" Or "," & ")
    new_nomes=new_nomes.replace(" X "," & ")
    new_nomes=new_nomes.replace(" x "," & ")
    for i in dic_bugs:
        if i in new_nomes:
            new_nomes=new_nomes.replace(i,dic_bugs[i])
    return re.split(r'\s[,&+]\s', new_nomes)

# %%
def insertfeat(lista_mc,lista,songid):
    
    for i in lista:
        if [songid,i] not in lista_mc:
            lista_mc.append([songid,i])

# %%
lista_musicas={}
for i in dic_dataframe:
    lista=[]
    for j in dic_dataframe[i].index:
        if dic_dataframe[i]['SongFiltred'][j] not in lista:
            lista.append(dic_dataframe[i]['SongFiltred'][j])
    lista_musicas[i]=lista

# %%
def conv_string_to_list(string):
    new=string.replace("'","")
    new=new.replace('"',"")
    new=new.strip('][').split(', ')
    return new

# %%
lista_cantores={}
lista_participacao={}
lista_generos={}
dic_SongID_Performers={}
lista_musicas_generos={}

for i in dic_dataframe:
    lista_s=[]
    lista_p=[]
    lista_g=[]
    lista_mg=[]
    
    for j in dic_dataframe[i].index:
        lista_singers = parse(dic_dataframe[i]["Performer_x"][j])
        for k in lista_singers:
            if k not in lista_s:
                lista_s.append(k)
                
        if len(lista_singers)>1:
            insertfeat(lista_p,lista_singers,dic_dataframe[i]["SongFiltred"][j])  
        print(dic_dataframe[i]["spotify_genre"][j],j)
        gen=conv_string_to_list(dic_dataframe[i]["spotify_genre"][j])
        
    
        for k in range(len(gen)):
            if gen[k] not in lista_g:
                lista_g.append(gen[k])
            lista_mg.append([dic_dataframe[i]["SongFiltred"][j],gen[k]])
    
    lista_musicas_generos[i]=lista_mg
    lista_generos[i]=lista_g
    lista_cantores[i]=lista_s
    lista_participacao[i]=lista_p
# Out:
# ['dance pop', 'pop'] 119
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'puerto rican pop'] 234
# ['urban contemporary'] 335
# ['country'] 389
# ['dance pop', 'pop', 'r&b', 'urban contemporary'] 643
# ['crunk', 'dirty south rap', 'gangster rap', 'new orleans rap'] 1125
# ['dance pop', 'girl group', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 1145
# ['neo mellow', 'pop rock', 'post-grunge'] 1174
# ['hip pop', 'neo soul', 'r&b', 'urban contemporary'] 1196
# ['contemporary country', 'country', 'country road', 'modern country rock'] 1202
# ['country', 'country dawn', 'dance pop', 'pop rock'] 1220
# ['album rock', 'art rock', 'classic rock', 'folk', 'folk rock', 'heartland rock', 'mellow gold', 'new wave pop', 'pop rock', 'rock', 'roots rock', 'singer-songwriter', 'soft rock', 'yacht rock'] 1249
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'pop', 'tropical'] 1255
# ['dance pop', 'girl group', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 1256
# ['contemporary country', 'country', 'country road'] 1282
# ['alternative metal', 'funk metal', 'nu metal', 'post-grunge', 'rap metal', 'wrestling'] 1299
# ['dance pop', 'europop', 'pop'] 1352
# ['alternative r&b', 'escape room', 'indie r&b', 'indie soul', 'nc hip hop'] 1365
# ['dance pop', 'deep pop r&b', 'hip pop', 'neo soul', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 1373
# ['chicago rap', 'hip hop', 'hip pop', 'new jack swing', 'r&b', 'urban contemporary'] 1375
# ['dance pop', 'pop', 'r&b'] 1389
# ['acoustic pop', 'neo mellow', 'pop rock', 'post-grunge'] 1391
# ['contemporary country', 'country', 'country road'] 1460
# ['contemporary country', 'country', 'country road'] 1475
# ['rap kreyol'] 1498
# ['country', 'country road', 'modern country rock'] 1601
# ['arkansas country', 'country', 'country road', 'country rock'] 1637
# ['deep latin christian', 'latin', 'latin pop', 'puerto rican pop', 'tropical'] 1642
# ['boy band', 'dance pop', 'pop'] 1752
# ['dance pop', 'pop'] 1819
# ['alternative rock', 'dance pop', 'permanent wave', 'pop rock', 'post-grunge'] 1963
# ['glam rock', 'mellow gold', 'piano rock'] 2132
# ['dance pop', 'pop', 'post-teen pop', 'r&b'] 2162
# ['dance pop', 'east coast hip hop', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'queens hip hop', 'rap', 'urban contemporary'] 2222
# ['canadian pop', 'dance pop'] 2292
# ['dance pop', 'deep pop r&b', 'hip pop', 'neo soul', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 2351
# ['neo mellow', 'pop rock', 'post-grunge'] 2482
# ['boy band', 'dance pop'] 2559
# ['candy pop', 'dance pop', 'europop', 'girl group', 'norwegian pop', 'pop rock'] 2565
# ['dance pop', 'pop', 'r&b', 'urban contemporary'] 2614
# ['contemporary country', 'country', 'country road'] 2731
# ['candy pop'] 2799
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 2833
# ['contemporary country', 'country', 'country road'] 2947
# ['contemporary country', 'country', 'country dawn', 'country road'] 3001
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 3030
# ['dance pop', 'hollywood', 'movie tunes', 'neo mellow', 'pop', 'pop rock', 'post-teen pop'] 3079
# ['disco house', 'vocal house'] 3102
# ['dance pop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 3153
# ['contemporary country', 'country', 'country dawn', 'country road', 'pop rock'] 3206
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'pop', 'tropical'] 3288
# ['boy band', 'dance pop', 'pop'] 3331
# ['pop punk', 'punk', 'socal pop punk'] 3352
# ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'post-grunge', 'rock'] 3378
# ['neo mellow', 'pop rock'] 3397
# ['east coast hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 3411
# ['alternative metal', 'nu metal', 'post-grunge', 'rock'] 3420
# ['australian pop', 'boy band', 'dance pop', 'europop', 'pop rock'] 3464
# ['alternative rock', 'neo mellow', 'permanent wave', 'pop rock', 'post-grunge'] 3532
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 3695
# ['canadian indie', 'canadian pop', 'canadian rock', 'comic', 'pop rock', 'post-grunge'] 3729
# ['eurodance', 'europop'] 3730
# ['contemporary country', 'country', 'country dawn', 'country road'] 3785
# ['alternative metal', 'alternative rock', 'grunge', 'industrial metal', 'industrial rock', 'nu metal', 'pop rock', 'post-grunge', 'rap rock', 'rock'] 3816
# ['dance pop', 'deep pop r&b', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'r&b', 'urban contemporary'] 3847
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 3890
# ['permanent wave', 'soft rock'] 4039
# ['atl hip hop', 'dance pop', 'girl group', 'hip hop', 'hip pop', 'new jack swing', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 4214
# ['funk', 'hip hop', 'neo soul', 'r&b', 'soul', 'urban contemporary'] 4373
# ['boy band', 'dance pop'] 4463
# ['alternative metal', 'comic', 'funk metal', 'funk rock', 'nu metal', 'punk', 'rap rock'] 4514
# ['alternative hip hop', 'east coast hip hop', 'hardcore hip hop', 'hip hop', 'neo soul', 'queens hip hop'] 4579
# ['dance pop', 'pop', 'r&b'] 4580
# ['east coast hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 4639
# ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'post-grunge', 'rock'] 4640
# ['gospel', 'gospel r&b'] 4658
# ['dance pop', 'post-teen pop'] 4670
# ['country', 'country dawn', 'country rock'] 4730
# ['gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'rap'] 4755
# ['dance pop', 'electropop', 'hip pop', 'neo soul', 'pop rap', 'r&b', 'urban contemporary'] 4763
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop', 'pop rap', 'r&b', 'southern hip hop', 'urban contemporary'] 4857
# ['alternative metal', 'alternative rock', 'grunge', 'hard rock', 'nu metal', 'pop rock', 'post-grunge', 'rock'] 4926
# ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge', 'rock'] 4970
# ['hip hop', 'new orleans rap', 'pop rap', 'rap', 'trap'] 4972
# ['hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 4975
# ['girl group', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 5001
# ['crunk', 'dirty south rap', 'gangster rap', 'hip hop', 'hip pop', 'miami hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 5007
# ['contemporary country', 'country', 'country road'] 5049
# ['contemporary country', 'country', 'country road', 'country rock', 'outlaw country'] 5162
# ['boy band', 'dance pop', 'europop'] 5167
# ['contemporary country', 'country', 'country road'] 5199
# ['contemporary country', 'country', 'country dawn'] 5225
# ['blues rock', 'classic rock'] 5342
# ['boy band', 'dance pop'] 5404
# ['contemporary country', 'country', 'country dawn'] 5655
# ['dance pop', 'pop'] 5677
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary'] 5780
# ['alternative rock', 'grunge', 'permanent wave', 'post-grunge', 'rock'] 5865
# ['dance pop', 'pop', 'post-teen pop', 'r&b'] 5891
# ['new jack swing', 'r&b'] 5957
# ['neo mellow', 'pop rock', 'post-grunge'] 5958
# ['atl hip hop', 'dirty south rap', 'hip hop', 'rap', 'southern hip hop'] 6079
# ['dance pop', 'reggae fusion'] 6171
# ['new jack swing', 'r&b', 'urban contemporary'] 6257
# ['dance pop', 'pop', 'post-teen pop'] 6364
# ['contemporary country', 'country', 'country dawn'] 6931
# ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'] 7082
# ['contemporary country', 'country', 'country road', 'country rock', 'modern country rock'] 7159
# ['alternative rock', 'mellow gold', 'neo mellow', 'pop rock', 'post-grunge', 'rock'] 7368
# ['alternative metal', 'permanent wave', 'post-grunge', 'punk', 'rock', 'skate punk', 'socal pop punk'] 7404
# ['alberta country', 'canadian contemporary country', 'canadian country', 'contemporary country', 'country', 'country dawn', 'country road'] 7449
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'puerto rican pop'] 7490
# ['contemporary country', 'country', 'country road', 'modern country rock'] 7678
# ['contemporary country', 'country', 'country road', 'country rock', 'redneck'] 7750
# ['deep pop r&b', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 7827
# ['hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 7986
# ['dance pop', 'hip pop', 'neo soul', 'new jack swing', 'pop', 'quiet storm', 'r&b', 'urban contemporary'] 8039
# ['boy band'] 8040
# ['dance pop', 'post-teen pop'] 8041
# ['glam metal', 'rock'] 8107
# ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge', 'rock'] 8180
# ['neo soul', 'soul'] 8431
# ['neo mellow', 'pop rock', 'post-grunge'] 8432
# ['dance pop', 'hollywood', 'movie tunes', 'neo mellow', 'pop', 'pop rock', 'post-teen pop'] 8520
# ['alternative metal', 'alternative rock', 'funk metal', 'neo mellow', 'pop rock', 'post-grunge'] 8620
# ['neo mellow', 'pop rock', 'post-grunge'] 8621
# ['dance pop', 'deep pop r&b', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'r&b', 'urban contemporary'] 8622
# ['grunge pop', 'pop rock', 'post-grunge'] 8723
# ['contemporary country', 'country', 'country road'] 8724
# ['dance pop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'urban contemporary'] 8725
# ['dancehall', 'reggae fusion', 'soca'] 8848
# ['contemporary country', 'country', 'country road'] 8978
# ['dance pop', 'girl group', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 9111
# ['country', 'country road', 'country rock', 'redneck'] 9112
# ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'] 9248
# ['hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 9249
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal', 'rap rock'] 9250
# ['contemporary country', 'country', 'country road'] 9251
# ['dance pop', 'pop', 'post-teen pop'] 9411
# ['contemporary country', 'country', 'country road'] 9412
# ['new jack swing', 'r&b', 'urban contemporary'] 9413
# ['dance pop', 'hip pop', 'neo soul', 'new jack swing', 'pop', 'quiet storm', 'r&b', 'urban contemporary'] 9414
# ['alternative metal', 'nu metal', 'pop rock', 'post-grunge'] 9415
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 9603
# ['deep southern trap', 'dirty south rap', 'new orleans rap'] 9604
# ['atl hip hop', 'dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'quiet storm', 'r&b', 'southern hip hop', 'urban contemporary'] 9605
# ['country', 'country dawn', 'dance pop', 'pop rock'] 9606
# ['dance pop', 'latin pop', 'new wave pop', 'soft rock'] 9607
# ['dance pop', 'hip pop', 'new jack swing', 'r&b', 'urban contemporary'] 9608
# ['alternative metal', 'alternative rock', 'nu metal', 'pop rock', 'post-grunge', 'rap rock'] 9609
# ['hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 9610
# ['permanent wave', 'pop rock', 'rock'] 9779
# ['contemporary country', 'country', 'country dawn', 'country road'] 9965
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary'] 9966
# ['dance pop', 'east coast hip hop', 'escape room', 'hip hop', 'hip pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap queen', 'urban contemporary'] 9967
# ['arkansas country', 'contemporary country', 'country', 'country road', 'country rock'] 10157
# ['dance pop', 'east coast hip hop', 'escape room', 'hip hop', 'hip pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap queen', 'urban contemporary'] 10158
# ['dance pop', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 10360
# ['hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 10413
# ['boy band'] 10416
# ['alternative metal', 'nu metal', 'pop rock', 'post-grunge'] 10596
# ['dance pop', 'europop'] 10597
# ['country', 'country road', 'country rock', 'oklahoma country', 'redneck'] 10598
# ['contemporary country', 'country', 'country road', 'modern country rock'] 10599
# ['country', 'country rock', 'oklahoma country'] 10836
# ['latin', 'latin pop', 'modern salsa', 'salsa', 'tropical'] 10837
# ['atl hip hop', 'boy band', 'dance pop', 'gangster rap', 'hip pop', 'new jack swing', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'urban contemporary'] 10838
# ['dance pop', 'pop', 'r&b'] 11089
# ['contemporary country', 'country', 'country dawn', 'country road'] 11090
# ['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 11321
# ['funk', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'soul', 'urban contemporary'] 11322
# ['contemporary country', 'country', 'country road', 'country rock', 'modern country rock', 'redneck'] 11323
# ['deep pop r&b', 'hip pop', 'r&b', 'urban contemporary'] 11571
# ['dance pop', 'pop', 'post-teen pop'] 11572
# ['australian pop', 'bubblegum dance', 'dance pop', 'europop'] 11573
# ['hard rock', 'metal', 'old school thrash', 'rock', 'speed metal', 'thrash metal'] 11848
# ['country', 'country dawn'] 11849
# ['hard rock', 'metal', 'old school thrash', 'rock', 'speed metal', 'thrash metal'] 11850
# ['candy pop', 'dance pop', 'europop', 'girl group', 'norwegian pop', 'pop rock'] 12126
# ['contemporary country', 'country', 'country road'] 12127
# ['contemporary country', 'country', 'country dawn', 'oklahoma country'] 12707
# ['alternative r&b', 'dance pop', 'neo soul', 'quiet storm', 'r&b', 'urban contemporary'] 12708
# ['french pop', 'operatic pop'] 13301
# ['australian pop', 'dance pop', 'europop'] 13542
# ['deep pop r&b', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 13543
# ['bronx hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'pop rap', 'rap', 'trap'] 14078
# ['dance pop', 'hip hop', 'hip pop', 'philly rap', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 14079
# ['country'] 14080
# ['country'] 14370
# ['ccm', 'christian alternative rock', 'christian music', 'worship'] 14502
# ['boy band'] 14670
# ['dance pop', 'europop'] 14702
# ['alternative hip hop', 'chicago rap', 'conscious hip hop', 'gangster rap', 'hip hop', 'rap'] 14743
# ['contemporary country', 'country', 'country road', 'country rock'] 14750
# ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'] 14835
# ['contemporary country', 'country', 'country dawn', 'country road'] 14909
# ['country', 'oklahoma country'] 14998
# ['contemporary country', 'country', 'country road', 'country rock', 'modern country rock', 'redneck'] 15103
# ['canadian pop', 'dance pop', 'deep pop r&b', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 15494
# ['boy band', 'new jack swing', 'pop', 'quiet storm', 'r&b', 'urban contemporary'] 15495
# ['dance pop', 'girl group', 'hip pop', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 15692
# ['new jack swing', 'urban contemporary'] 16058
# ['funk', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'soul', 'urban contemporary'] 16192
# ['deep pop r&b', 'hip pop', 'miami hip hop', 'pop rap', 'r&b', 'rap', 'rap latina', 'southern hip hop', 'trap', 'trap queen'] 16334
# ['alternative hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap', 'southern hip hop'] 16491
# ['deep southern trap', 'dirty south rap', 'gangster rap', 'hip hop', 'new orleans rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 16492
# ['dance pop', 'hip pop', 'neo soul', 'new jack swing', 'pop', 'quiet storm', 'r&b', 'urban contemporary'] 16493
# ['boy band', 'dance pop', 'pop'] 16536
# ['country', 'country road', 'country rock', 'oklahoma country', 'redneck'] 16593
# ['detroit hip hop', 'g funk', 'hip hop', 'rap'] 16606
# ['detroit hip hop', 'g funk', 'hip hop', 'rap'] 16758
# ['contemporary country', 'country', 'country dawn', 'country road', 'pop rock'] 16785
# ['contemporary country', 'country', 'country dawn', 'country road'] 16888
# ['contemporary country', 'country', 'country dawn', 'country road'] 16908
# ['dance pop', 'pop', 'post-teen pop'] 16911
# ['contemporary country', 'country', 'country road'] 17030
# ['boy band', 'dance pop', 'neo mellow', 'pop rock'] 17107
# ['contemporary country', 'country', 'country dawn', 'country road'] 17124
# ['dance pop', 'hip pop', 'new jack swing', 'r&b', 'urban contemporary'] 17131
# ['bronx hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'rap', 'southern hip hop'] 17428
# ['girl group', 'hip pop', 'r&b', 'urban contemporary'] 17429
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'rap', 'southern hip hop'] 17430
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 17696
# ['alternative hip hop', 'conscious hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap', 'southern hip hop'] 17697
# ['dance pop', 'deep pop r&b', 'hip pop', 'neo soul', 'r&b', 'urban contemporary'] 18023
# ['east coast hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 18024
# ['emo', 'pop punk'] 18025
# ['hip hop'] 18350
# ['east coast hip hop', 'hardcore hip hop', 'hip hop', 'hip pop', 'old school hip hop', 'pop rap', 'queens hip hop', 'r&b', 'rap', 'southern hip hop', 'urban contemporary'] 18351
# ['german techno'] 18352
# ['contemporary country', 'country', 'country road', 'modern country rock'] 18353
# ['dirty south rap', 'gangster rap', 'hip hop', 'philly rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 18673
# ['neo r&b', 'neo soul', 'r&b'] 18674
# ['country', 'country road'] 18675
# ['alternative metal', 'alternative rock', 'permanent wave', 'pop rock', 'post-grunge', 'rock'] 19163
# ['detroit hip hop', 'g funk', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'] 19284
# ['country', 'country road'] 19324
# ['country rap', 'lgbtq+ hip hop', 'pop rap'] 19598
# ['latin', 'latin pop', 'modern salsa', 'salsa', 'tropical'] 19606
# ['deep pop r&b', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 19622
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 19623
# ['country', 'country road'] 19665
# ['contemporary country', 'country', 'country road', 'country rock'] 19674
# ['neo mellow', 'pop rock', 'post-grunge'] 19690
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 19874
# ['atl hip hop', 'dance pop', 'dirty south rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 19889
# ['contemporary country', 'country', 'country road', 'modern country rock'] 20047
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 20111
# ['dance pop', 'post-teen pop'] 20139
# ['atl hip hop', 'crunk', 'dance pop', 'dirty south rap', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 20174
# ['bahamian pop'] 20236
# ['hardcore hip hop', 'harlem hip hop', 'hip hop', 'hip pop'] 20287
# ['boy band', 'dance pop', 'hip hop', 'hip pop', 'minneapolis sound', 'neo soul', 'new jack swing', 'pop rap', 'quiet storm', 'r&b', 'urban contemporary'] 20364
# ['country', 'oklahoma country'] 20373
# ['alternative metal', 'nu metal', 'pop rock', 'post-grunge', 'rock'] 20477
# ['contemporary country', 'country', 'country dawn'] 20512
# ['dirty south rap', 'southern hip hop'] 20524
# ['australian country', 'contemporary country', 'country', 'country road'] 20538
# ['bronx hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'pop rap', 'rap', 'trap'] 20941
# ['latin pop'] 20951
# ['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 21013
# ['bounce', 'crunk', 'dirty south rap', 'gangster rap', 'hip hop', 'new orleans rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 21185
# ['alternative r&b', 'funk', 'hip hop', 'indie soul', 'neo soul', 'r&b', 'soul', 'urban contemporary'] 21278
# ['contemporary country', 'country', 'country road'] 21690
# ['boy band'] 21832
# ['contemporary country', 'country', 'country road'] 21871
# ['contemporary country', 'country', 'country road'] 21929
# ['harlem hip hop'] 21971
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 22009
# ['chicago rap', 'hip hop', 'hip pop', 'new jack swing', 'r&b', 'urban contemporary'] 22015
# ['dance pop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 82
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 111
# ['dance pop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'urban contemporary'] 194
# ['alternative metal', 'funk metal', 'nu metal', 'post-grunge', 'rap rock'] 206
# ['canadian pop', 'dance pop', 'deep pop r&b', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 253
# ['contemporary country', 'country', 'country road'] 257
# ['alternative metal', 'alternative rock', 'art rock', 'nu metal', 'post-grunge', 'post-metal', 'progressive metal', 'progressive rock', 'rock'] 394
# ['funk', 'hip hop', 'hip pop', 'neo soul', 'r&b', 'soul', 'urban contemporary'] 401
# ['atl hip hop', 'boy band', 'dance pop', 'gangster rap', 'hip pop', 'new jack swing', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'urban contemporary'] 944
# ['permanent wave', 'pop rock', 'rock'] 952
# ['dance pop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 1039
# ['dance pop', 'electropop', 'pop', 'pop rap', 'post-teen pop'] 1085
# ['dance pop', 'pop', 'post-teen pop'] 1135
# ['contemporary country', 'country', 'country road', 'modern country rock'] 1215
# ['bubblegum dance', 'eurodance'] 1226
# ['alternative metal', 'alternative rock', 'nu metal', 'pop rock', 'post-grunge', 'rap rock'] 1264
# ['atl hip hop', 'dance pop', 'dirty south rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 1272
# ['acoustic pop', 'neo mellow', 'permanent wave', 'pop rock'] 1290
# ['adult standards', 'disco', 'mellow gold', 'motown', 'quiet storm', 'soft rock'] 1336
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal'] 1356
# ['hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 1387
# ['alternative metal', 'funk metal', 'nu metal', 'post-grunge', 'rap metal', 'wrestling'] 1410
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal'] 1413
# ['contemporary country', 'country', 'country road'] 1458
# ['contemporary country', 'country', 'country road'] 1464
# ['neo soul', 'new jack swing', 'r&b', 'urban contemporary'] 1510
# ['contemporary country', 'country', 'country dawn', 'country road'] 1539
# ['atl hip hop', 'boy band', 'dance pop', 'gangster rap', 'hip pop', 'new jack swing', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'urban contemporary'] 1591
# ['contemporary country', 'country', 'country dawn', 'country road'] 1635
# ['funk', 'motown', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'soul', 'urban contemporary'] 1736
# ['dance pop', 'girl group', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 1820
# ['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 2163
# ['crunk', 'dirty south rap', 'gangster rap', 'new orleans rap'] 2255
# ['detroit hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'rap rock', 'southern hip hop'] 2372
# ['hip pop'] 2381
# ['hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 2483
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary'] 2496
# ['classic soul', 'disco', 'funk', 'motown', 'quiet storm', 'soul', 'southern soul'] 2499
# ['dance pop', 'new wave pop', 'pop rock'] 2522
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop', 'pop rap', 'r&b', 'southern hip hop', 'urban contemporary'] 2604
# ['contemporary country', 'country', 'country road', 'country rock', 'modern country rock', 'redneck'] 2748
# ['crunk', 'dirty south rap', 'gangster rap', 'hip hop', 'hip pop', 'miami hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 2767
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 3031
# ['electro', 'filter house'] 3107
# ['neo mellow', 'pop rock', 'post-grunge'] 3112
# ['dance pop', 'reggae fusion'] 3154
# ['bronx hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'pop rap', 'rap', 'trap'] 3259
# ['dance pop', 'east coast hip hop', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'queens hip hop', 'rap', 'urban contemporary'] 3298
# ['celtic', 'middle earth'] 3307
# ['dance pop', 'hip pop', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 3319
# ['acoustic pop', 'neo mellow', 'piano rock', 'pop rock', 'post-grunge'] 3380
# ['dance pop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'urban contemporary'] 3398
# ['atl hip hop', 'dance pop', 'dirty south rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 3456
# ['atl hip hop', 'dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'quiet storm', 'r&b', 'southern hip hop', 'urban contemporary'] 3465
# ['alternative metal', 'funk metal', 'nu metal', 'post-grunge', 'rap rock', 'rock'] 3840
# ['contemporary country', 'country', 'country road', 'country rock'] 3867
# ['big beat', 'ninja', 'trip hop', 'turntablism'] 4041
# ['boy band', 'dance pop'] 4098
# ['irish rock', 'permanent wave', 'rock'] 4175
# ['dance pop', 'girl group', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 4330
# ['gangster rap', 'hip hop', 'rap'] 4374
# ['glam metal', 'rock'] 4421
# ['atl hip hop', 'dirty south rap', 'hip hop', 'rap', 'southern hip hop'] 4581
# ['alternative metal', 'nu metal', 'pop rock', 'post-grunge'] 4641
# ['dance pop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 4642
# ['detroit hip hop', 'g funk', 'hip hop', 'rap'] 4698
# ['country', 'country dawn', 'country road'] 4757
# ['indie soul', 'neo r&b', 'neo soul'] 4823
# ['bounce', 'crunk', 'dirty south rap', 'gangster rap', 'hip hop', 'new orleans rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 4880
# ['alternative hip hop', 'art pop'] 4951
# ['crunk', 'dirty south rap', 'gangster rap', 'memphis hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 4957
# ['british soul', 'neo soul'] 4973
# ['country', 'country dawn', 'deep contemporary country'] 5048
# ['downtempo', 'electronica'] 5124
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 5125
# ['irish rock', 'permanent wave', 'rock'] 5126
# ['crunk', 'dirty south rap', 'gangster rap', 'hip pop', 'nc hip hop', 'pop rap', 'southern hip hop'] 5158
# ['dance pop', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'r&b', 'rap', 'trap'] 5161
# ['contemporary country', 'country', 'country road', 'country rock'] 5187
# ['dance pop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 5202
# ['contemporary country', 'country', 'country road', 'country rock'] 5213
# ['contemporary country', 'country', 'country dawn', 'country gospel', 'country road'] 5248
# ['australian pop', 'bow pop', 'celtic rock', 'dance pop', 'europop', 'neo mellow', 'new wave pop', 'pop rock'] 5254
# ['country', 'country rock'] 5355
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'pop', 'tropical'] 5738
# ['alternative metal', 'nu metal', 'pop rock', 'post-grunge', 'rock'] 5892
# ['boy band', 'dance pop', 'pop'] 6042
# ['hip pop', 'neo soul', 'r&b', 'urban contemporary'] 6080
# ['album rock', 'classic rock', 'hard rock', 'rock'] 6214
# ['east coast hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 6258
# ['alternative hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'rap', 'turntablism'] 6307
# ['australian pop', 'bubblegum dance', 'dance pop', 'europop', 'post-teen pop'] 6365
# ['candy pop', 'dance pop', 'lilith', 'neo mellow', 'pop rock', 'post-teen pop'] 6420
# ['alternative rock', 'dance pop', 'permanent wave', 'pop rock', 'post-grunge'] 6421
# ['permanent wave', 'pop rock', 'rock'] 6467
# ['australian country', 'contemporary country', 'country', 'country road'] 6643
# ['bubble trance', 'eurodance'] 7102
# ['boy band', 'dance pop', 'pop'] 7150
# ['contemporary country', 'country', 'country road', 'modern country rock'] 7491
# ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'] 7530
# ['dance pop', 'pop', 'pop rap'] 7531
# ['contemporary country', 'country', 'country road', 'modern country rock'] 7898
# ['boy band'] 8181
# ['dance pop', 'girl group', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 8182
# ['canadian latin', 'canadian pop', 'dance pop', 'pop', 'pop rap', 'pop rock'] 8270
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary'] 8271
# ['neo mellow', 'pop rock', 'post-grunge'] 8433
# ['boy band', 'dance pop', 'pop'] 8434
# ['dance pop', 'pop', 'post-teen pop'] 8435
# ['contemporary country', 'country', 'country road'] 8521
# ['dance pop', 'post-teen pop'] 8522
# ['british soul', 'dance pop', 'pop', 'r&b', 'tropical house', 'urban contemporary'] 8523
# ['pop punk'] 8524
# ['dance pop', 'pop', 'post-teen pop'] 8525
# ['contemporary country', 'country', 'country road'] 8623
# ['dance pop', 'pop', 'post-teen pop', 'r&b'] 8624
# ['contemporary country', 'country', 'country road', 'modern country rock'] 8625
# ['bronx hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'pop rap', 'rap', 'trap'] 8626
# ['deep pop r&b', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 8726
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 8727
# ['country', 'country road', 'neo mellow', 'pop rock', 'post-grunge'] 8849
# ['dance pop', 'funk', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'soul', 'urban contemporary'] 8850
# ['alternative metal', 'alternative rock', 'pop rock', 'post-grunge'] 9113
# ['dance pop', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 9114
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 9115
# ['dance pop', 'deep pop r&b', 'hip pop', 'neo soul', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 9252
# ['alternative metal', 'alternative rock', 'funk metal', 'funk rock', 'modern rock', 'nu metal', 'pop rock', 'post-grunge', 'rock'] 9253
# ['contemporary country', 'country', 'country dawn'] 9254
# ['alternative metal', 'canadian pop punk', 'canadian punk', 'nu metal', 'pop punk', 'post-grunge', 'punk'] 9255
# ['alternative metal', 'canadian rock', 'nu metal', 'post-grunge'] 9256
# ['jam band', 'neo mellow', 'pop rock'] 9416
# ['alternative metal', 'neo mellow', 'pop rock', 'post-grunge'] 9417
# ['contemporary country', 'country', 'country road'] 9418
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 9419
# ['contemporary country', 'country', 'country road', 'country rock', 'outlaw country'] 9420
# ['alternative metal', 'nu metal', 'post-grunge', 'rap rock', 'rock'] 9421
# ['alternative r&b', 'dance pop', 'neo soul', 'quiet storm', 'r&b', 'urban contemporary'] 9611
# ['contemporary country', 'country', 'country dawn', 'country road'] 9612
# ['contemporary country', 'country', 'country road', 'country rock', 'modern country rock', 'redneck'] 9613
# ['atl hip hop', 'dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'quiet storm', 'r&b', 'southern hip hop', 'urban contemporary'] 9614
# ['contemporary country', 'country', 'country road', 'country rock', 'outlaw country'] 9780
# ['alternative rock', 'pop rock', 'post-grunge'] 9781
# ['dance pop', 'east coast hip hop', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'queens hip hop', 'rap', 'urban contemporary'] 9782
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal'] 9783
# ['alternative metal', 'nu metal', 'post-grunge', 'rap rock', 'rock'] 9968
# ['contemporary country', 'country', 'country dawn', 'country road', 'pop rock'] 10159
# ['contemporary country', 'country', 'country dawn', 'country road'] 10160
# ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'] 10161
# ['dance pop', 'hip hop', 'hip pop', 'philly rap', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 10162
# ['eurodance', 'europop', 'finnish edm'] 10414
# ['alternative metal', 'funk metal', 'nu metal', 'post-grunge', 'rap metal', 'wrestling'] 10600
# ['contemporary country', 'country', 'country dawn', 'country road'] 10601
# ['contemporary country', 'country', 'country dawn', 'oklahoma country'] 10602
# ['hip pop'] 10839
# ['dance pop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 10840
# ['contemporary country', 'country', 'country dawn', 'country gospel', 'country road'] 11091
# ['hip pop', 'r&b', 'urban contemporary'] 11092
# ['alternative rock', 'permanent wave', 'pop rock', 'rock'] 11093
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 11094
# ['contemporary country', 'country', 'country road', 'modern country rock'] 11095
# ['dance rock', 'new romantic', 'new wave', 'permanent wave', 'synthpop'] 11574
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'quiet storm', 'r&b', 'southern hip hop', 'urban contemporary'] 12128
# ['alternative country', 'folk', 'indie folk', 'new americana', 'roots rock'] 12129
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 13544
# ['dance pop', 'east coast hip hop', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'queens hip hop', 'rap', 'urban contemporary'] 13545
# ['alternative r&b', 'dance pop', 'neo soul', 'quiet storm', 'r&b', 'urban contemporary'] 13797
# ['disco house', 'filter house', 'vocal house'] 14371
# ['new jack swing', 'r&b', 'urban contemporary'] 14372
# ['contemporary country', 'country', 'country road', 'country rock'] 14758
# ['atl hip hop', 'deep pop r&b', 'hip pop', 'r&b', 'urban contemporary'] 15496
# ['girl group', 'hip pop', 'r&b', 'urban contemporary'] 15591
# ['bubblegum dance', 'dance pop', 'europop'] 15806
# ['atl hip hop', 'crunk', 'dance pop', 'dirty south rap', 'pop rap', 'southern hip hop'] 15927
# ['dance pop', 'post-teen pop'] 16193
# ['philly rap'] 16494
# ['atl hip hop', 'dirty south rap', 'hip hop', 'hip pop', 'pop rap', 'rap', 'southern hip hop'] 16495
# ['pop punk', 'punk', 'socal pop punk'] 16632
# ['jam band', 'neo mellow', 'pop rock'] 16678
# ['funk', 'hip hop', 'hip pop', 'neo soul', 'r&b', 'soul', 'urban contemporary'] 16790
# ['atl hip hop', 'dirty south rap', 'hip hop', 'rap', 'southern hip hop'] 16806
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop', 'pop rap', 'r&b', 'southern hip hop', 'urban contemporary'] 16891
# ['dance pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 16896
# ['contemporary country', 'country', 'country dawn', 'country road', 'pop rock'] 16913
# ['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'southern hip hop', 'trap', 'urban contemporary'] 17059
# ['deep norteno', 'duranguense', 'musica potosina', 'norteno', 'norteno-sax'] 17431
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'new jersey rap', 'rap', 'southern hip hop', 'wu fam'] 17698
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'puerto rican pop'] 17699
# ['album rock', 'classic rock', 'folk rock', 'mellow gold', 'rock', 'soft rock'] 17700
# ['alberta country', 'canadian country', 'country', 'country dawn'] 18026
# ['hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 18027
# ['country', 'country dawn', 'country road'] 18028
# ['milwaukee hip hop'] 18029
# ['bubblegum dance'] 18354
# ['candy pop'] 18355
# ['dirty south rap', 'southern hip hop'] 18356
# ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'] 18357
# ['crunk', 'dirty south rap', 'gangster rap', 'hip hop', 'hip pop', 'miami hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 18358
# ['hip pop'] 18359
# ['country rap', 'lgbtq+ hip hop', 'pop rap'] 18360
# ['hip hop', 'new orleans rap', 'pop rap', 'rap', 'trap'] 18932
# ['contemporary country', 'country', 'country road'] 19253
# ['country', 'oklahoma country'] 19254
# ['permanent wave', 'pop'] 19314
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 19497
# ['dance pop', 'pop', 'post-teen pop'] 19569
# ['pop', 'r&b', 'soul'] 19605
# ['fake'] 19854
# ['contemporary country', 'country', 'country dawn', 'country road'] 19964
# ['alternative metal', 'alternative rock', 'funk metal', 'neo mellow', 'pop rock', 'post-grunge'] 19984
# ['contemporary country', 'country', 'country road'] 19997
# ['colombian pop', 'dance pop', 'latin', 'latin pop', 'mexican pop', 'pop'] 20074
# ['contemporary country', 'country', 'country dawn', 'country road', 'pop rock'] 20081
# ['contemporary country', 'country', 'country road'] 20109
# ['australian country', 'contemporary country', 'country', 'country road'] 20121
# ['country', 'country road', 'country rock', 'redneck'] 20125
# ['contemporary country', 'country', 'country road'] 20132
# ['neo mellow', 'pop rock', 'post-grunge'] 20152
# ['contemporary country', 'country', 'country road'] 20155
# ['country', 'country dawn'] 20229
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 20252
# ['dance pop', 'hip hop', 'hip pop', 'philly rap', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 20279
# ['contemporary country', 'country', 'country dawn', 'country road'] 20338
# ['alternative metal', 'alternative rock', 'funk metal', 'funk rock', 'modern rock', 'nu metal', 'pop rock', 'post-grunge', 'rock'] 20457
# ['contemporary country', 'country', 'country road'] 20480
# ['canadian indie', 'canadian pop', 'canadian rock', 'comic', 'pop rock', 'post-grunge'] 20816
# ['canadian latin', 'canadian pop', 'dance pop', 'pop', 'pop rap', 'pop rock'] 21071
# ['contemporary country', 'country', 'country road'] 21152
# ['atl hip hop', 'dance pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 21176
# ['atl hip hop', 'dance pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 21181
# ['atl hip hop', 'country rap', 'dirty south rap', 'pop rap', 'redneck', 'southern hip hop'] 21189
# ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'] 21275
# ['neo soul', 'r&b', 'urban contemporary'] 21393
# ['r&b', 'urban contemporary'] 21429
# ['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 21726
# ['bronx hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'pop rap', 'rap', 'trap'] 21741
# ['atl hip hop', 'dirty south rap', 'hip hop', 'hip pop', 'pop rap', 'rap', 'southern hip hop'] 21806
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'quiet storm', 'r&b', 'southern hip hop', 'urban contemporary'] 21882
# ['country', 'country dawn'] 21931
# ['dance pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 21935
# ['dance pop', 'pop'] 21949
# ['brazilian death metal', 'brazilian metal', 'brazilian thrash metal', 'crossover thrash', 'groove metal', 'metal', 'new wave of thrash metal', 'speed metal', 'thrash metal'] 21951
# ['hip pop'] 21997
# ['contemporary country', 'country', 'country road', 'modern country rock'] 287
# ['contemporary country', 'country', 'country dawn', 'country road'] 336
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal', 'rock'] 376
# ['neo soul', 'r&b', 'soul', 'urban contemporary'] 430
# ['alternative metal', 'alternative rock', 'canadian rock', 'pop rock', 'post-grunge', 'wrestling'] 443
# ['battle rap', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'philly rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 448
# ['contemporary country', 'country', 'country dawn', 'country road', 'pop rock'] 459
# ['deep contemporary country'] 496
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary'] 604
# ['dance pop', 'pop'] 996
# ['big beat', 'disco house'] 1027
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 1046
# ['crunk', 'dirty south rap', 'gangster rap', 'new orleans rap'] 1228
# ['dirty south rap', 'gangster rap', 'pop rap', 'southern hip hop'] 1230
# ['acoustic pop', 'dance pop', 'lilith', 'neo mellow', 'piano rock', 'pop rock'] 1274
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal', 'rock'] 1277
# ['hip pop', 'neo soul', 'r&b', 'urban contemporary'] 1281
# ['country', 'country road', 'country rock'] 1283
# ['alternative metal', 'alternative rock', 'nu metal', 'post-grunge', 'rap rock', 'rock'] 1293
# ['contemporary country', 'country', 'country dawn'] 1390
# ['contemporary country', 'country', 'country road'] 1551
# ['alternative metal', 'funk metal', 'nu metal', 'post-grunge', 'rap metal', 'rap rock'] 1562
# ['dance pop', 'pop', 'pop rap'] 1838
# ['hip pop', 'neo soul', 'r&b', 'urban contemporary'] 2070
# ['dance pop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'urban contemporary'] 2071
# ['detroit hip hop', 'g funk', 'hip hop', 'rap'] 2072
# ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'post-grunge', 'rock'] 2103
# ['candy pop', 'dance pop', 'lilith', 'neo mellow', 'pop rock', 'post-teen pop'] 2316
# ['pop', 'r&b', 'soul'] 2393
# ['east coast hip hop', 'hardcore hip hop', 'hip hop', 'hip pop', 'pop rap', 'rap'] 2394
# ['british soul', 'dance pop', 'pop', 'r&b', 'tropical house', 'urban contemporary'] 2459
# ['alternative metal', 'alternative rock', 'nu metal', 'post-grunge', 'rap rock', 'rock'] 2471
# ['contemporary country', 'country', 'country road', 'modern country rock'] 2784
# ['alternative metal', 'funk metal', 'nu metal', 'pop rock', 'post-grunge'] 2813
# ['adult standards', 'contemporary vocal jazz', 'neo mellow', 'vocal jazz'] 2854
# ['atl hip hop', 'deep pop r&b', 'hip pop', 'r&b', 'urban contemporary'] 2985
# ['dance pop', 'latin', 'latin arena pop', 'latin pop', 'mexican pop'] 3096
# ['alternative metal', 'funk metal', 'nu metal', 'pop rock', 'post-grunge'] 3115
# ['dance pop', 'east coast hip hop', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'queens hip hop', 'rap', 'urban contemporary'] 3130
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary'] 3147
# ['canadian pop', 'candy pop', 'dance pop', 'pop', 'post-teen pop'] 3159
# ['acoustic pop', 'dance pop', 'lilith', 'neo mellow', 'piano rock', 'pop rock'] 3215
# ['alternative metal', 'nu metal', 'pop rock', 'post-grunge', 'rock'] 3222
# ['alternative metal', 'alternative rock', 'nu metal', 'post-grunge', 'rap rock', 'rock'] 3243
# ['crunk', 'dirty south rap', 'gangster rap', 'hip hop', 'new orleans rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 3358
# ['canadian pop', 'dance pop'] 3639
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 3752
# ['contemporary country', 'country', 'country road', 'country rock'] 3803
# ['australian country', 'contemporary country', 'country', 'country road'] 3833
# ['dance pop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 3851
# ['folk', 'lilith', 'mellow gold', 'neo mellow', 'new wave pop', 'permanent wave', 'pop rock', 'rock'] 3868
# ['neo mellow', 'pop rock', 'post-grunge'] 3886
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop', 'pop rap', 'r&b', 'southern hip hop', 'urban contemporary'] 3945
# ['alaska indie', 'lilith', 'permanent wave', 'pop rock', 'singer-songwriter'] 3971
# ['atl hip hop', 'dance pop', 'deep pop r&b', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'r&b', 'urban contemporary'] 4047
# ['dance pop', 'pop', 'post-teen pop'] 4099
# ['progressive trance', 'trance'] 4215
# ['australian dance', 'australian pop', 'dance pop', 'electropop', 'eurodance', 'europop', 'new wave pop', 'pop'] 4236
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 4280
# ['dance pop', 'pop', 'post-teen pop', 'r&b'] 4375
# ['boy band', 'dance pop'] 4422
# ['new jack swing', 'r&b', 'urban contemporary'] 4464
# ['dance pop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'urban contemporary'] 4465
# ['dance pop', 'deep pop r&b', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'quiet storm', 'r&b', 'urban contemporary'] 4515
# ['alternative rock', 'neo mellow', 'permanent wave', 'pop rock', 'post-grunge'] 4516
# ['alternative r&b', 'dance pop', 'deep pop r&b', 'hip hop', 'hip pop', 'neo soul', 'r&b', 'urban contemporary'] 4517
# ['contemporary country', 'country', 'country road'] 4582
# ['canadian pop', 'candy pop', 'dance pop', 'pop', 'post-teen pop'] 4643
# ['atl hip hop', 'crunk', 'dance pop', 'dirty south rap', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 4830
# ['modern rock', 'neo mellow', 'pop punk', 'pop rock', 'post-grunge', 'rock'] 4839
# ['hip pop', 'r&b'] 4845
# ['country rap', 'lgbtq+ hip hop', 'pop rap'] 4874
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal', 'rap rock'] 4910
# ['alternative hip hop', 'detroit hip hop', 'hip hop', 'indie soul', 'neo soul', 'southern hip hop'] 4958
# ['grupera', 'latin', 'latin arena pop', 'latin pop'] 4984
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap', 'southern hip hop'] 5005
# ['country', 'country road', 'country rock'] 5044
# ['alternative metal', 'permanent wave', 'post-grunge', 'punk', 'rock', 'skate punk', 'socal pop punk'] 5052
# ['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 5118
# ['dirty south rap', 'gangster rap', 'pop rap', 'southern hip hop'] 5127
# ['east coast hip hop', 'hardcore hip hop', 'hip hop', 'hip pop', 'pop rap', 'rap'] 5214
# ['atl hip hop', 'dance pop', 'dirty south rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 5241
# ['detroit hip hop', 'g funk', 'hip hop', 'rap'] 5713
# ['dance pop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'urban contemporary'] 5866
# ['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 6081
# ['dance pop', 'pop', 'post-teen pop'] 6215
# ['country rap', 'lgbtq+ hip hop', 'pop rap'] 6216
# ['dance pop', 'pop', 'post-teen pop'] 6366
# ['dance pop', 'hip hop', 'hip pop', 'philly rap', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 6367
# ['alternative metal', 'emo', 'pop punk', 'post-grunge'] 6368
# ['contemporary country', 'country', 'country road', 'country rock', 'redneck'] 6599
# ['electropop'] 7405
# ['dance pop', 'deep pop r&b', 'hip pop', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary'] 7450
# ['hip hop'] 7532
# ['alternative rock', 'neo mellow', 'permanent wave', 'pop rock', 'post-grunge'] 8042
# ['alternative rock', 'dance pop', 'permanent wave', 'pop rock', 'post-grunge'] 8043
# ['canadian pop', 'candy pop', 'dance pop', 'pop', 'post-teen pop'] 8044
# ['alternative rock', 'canadian pop', 'canadian singer-songwriter', 'pop rock', 'singer-songwriter'] 8183
# ['neo mellow', 'pop', 'pop rock', 'singer-songwriter'] 8184
# ['dancehall', 'reggae fusion', 'soca'] 8185
# ['canadian country', 'canadian pop', 'country', 'country dawn', 'dance pop'] 8186
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'queens hip hop', 'rap'] 8343
# ['contemporary country', 'country', 'country dawn'] 8344
# ['dance pop', 'pop', 'pop rap'] 8345
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary'] 8346
# ['dance pop', 'east coast hip hop', 'gangster rap', 'hip hop', 'hip pop', 'pop rap', 'queens hip hop', 'rap', 'urban contemporary'] 8347
# ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 8436
# ['colombian pop', 'dance pop', 'latin', 'latin pop', 'mexican pop', 'pop'] 8437
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary'] 8526
# ['alternative metal', 'post-grunge'] 8527
# ['candy pop', 'dance pop', 'lilith', 'neo mellow', 'pop rock', 'post-teen pop'] 8528
# ['contemporary country', 'country', 'country road', 'country rock', 'modern country rock', 'redneck'] 8529
# ['dance pop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'] 8530
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'pop', 'tropical'] 8627
# ['contemporary country', 'country', 'country dawn', 'country gospel', 'country road'] 8628
# ['country', 'country road', 'neo mellow', 'pop rock', 'post-grunge'] 8629
# ['east coast hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop'] 8728
# ['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 8729
# ['alberta country', 'canadian country', 'country', 'country dawn'] 8730
# ['atl hip hop', 'dance pop', 'girl group', 'hip hop', 'hip pop', 'new jack swing', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 8731
# ['country', 'country road', 'country rock', 'oklahoma country', 'redneck'] 8851
# ['contemporary country', 'country', 'country road'] 8852
# ['alternative metal', 'funk metal', 'nu metal', 'post-grunge', 'rap metal', 'rock'] 8853
# ...
# ['alternative r&b', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 6100
# ['hollywood', 'show tunes'] 6101
# ['chicago rap', 'melodic rap'] 6146
# ['dance pop', 'pop', 'post-teen pop'] 6147
# ['florida rap'] 6148
# ['dance pop', 'hip hop', 'miami hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 6187
# ['baton rouge rap', 'trap'] 6188
# ['chicago rap', 'conscious hip hop', 'hip hop', 'pop rap', 'rap'] 6232
# ['dfw rap', 'melodic rap', 'rap'] 6233
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 6273
# ['boston hip hop', 'hip hop', 'pop rap', 'rap'] 6274
# ['atl hip hop', 'atl trap', 'gangster rap', 'melodic rap', 'pop rap', 'rap', 'trap'] 6323
# ['chicago rap', 'rap'] 6324
# ['alternative r&b', 'pop', 'pop rap'] 6388
# ['electropop', 'pop'] 6436
# ['dance pop', 'pop', 'post-teen pop'] 6437
# ['dance pop', 'pop', 'post-teen pop'] 6438
# ['arkansas country', 'contemporary country', 'country pop'] 6739
# ['dance pop', 'pop', 'post-teen pop', 'tropical house', 'uk pop'] 6895
# ['alternative r&b', 'pop'] 6988
# ['alternative r&b', 'pop', 'viral pop'] 7057
# ['atl hip hop', 'hip hop', 'melodic rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 7074
# ['pop rap', 'rap', 'trap'] 7090
# ['brostep', 'progressive electro house'] 7103
# ['contemporary country', 'pop', 'texas country'] 7127
# ['melodic rap', 'rap', 'trap'] 7135
# ['emo rap', 'miami hip hop', 'rap', 'trap'] 7344
# ['canadian hip hop', 'melodic rap', 'pop rap', 'rap', 'toronto rap', 'trap'] 7345
# ['atl hip hop', 'atl trap', 'pop rap', 'rap', 'trap'] 7346
# ['contemporary country'] 7347
# ['melodic rap', 'rap', 'trap'] 7348
# ['nc hip hop', 'rap'] 7380
# ['alternative r&b', 'pop', 'pop rap'] 7381
# ['atl hip hop', 'hip hop', 'melodic rap', 'pop rap', 'rap', 'trap'] 7422
# ['hip hop', 'rap'] 7423
# ['hip hop', 'rap'] 7467
# ['dance pop', 'pop', 'post-teen pop'] 7468
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap'] 7469
# ['melodic rap', 'rap', 'trap'] 7470
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 7504
# ['melodic rap', 'philly rap', 'pop rap', 'rap', 'trap'] 7505
# ['conscious hip hop', 'dmv rap', 'hip hop', 'pop rap', 'rap'] 7595
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 7632
# ['electropop', 'pop'] 7633
# ['alternative r&b', 'pop', 'viral pop'] 7692
# ['melodic rap'] 7693
# ['alternative r&b', 'pop', 'pop rap'] 7694
# ['emo rap', 'miami hip hop', 'rap', 'trap'] 7770
# ['dance pop', 'pop', 'post-teen pop'] 7771
# ['k-hop', 'k-pop'] 7772
# ['electropop', 'pop'] 8067
# ['chicago rap', 'rap'] 8068
# ['hip hop', 'pop', 'pop rap', 'rap', 'toronto rap', 'trap', 'urban contemporary'] 8069
# ['melodic rap', 'rap', 'trap'] 8124
# ['contemporary country', 'country pop'] 8125
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 8216
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 8217
# ['chicago rap', 'melodic rap'] 8218
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 8219
# ['baton rouge rap', 'trap'] 8289
# ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap', 'underground hip hop'] 8372
# ['hip hop', 'rap'] 8373
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap'] 8460
# ['rap', 'trap'] 8461
# ['alternative r&b', 'dance pop', 'pop', 'pop rap', 'post-teen pop', 'r&b', 'rap', 'urban contemporary'] 8556
# ['dance pop', 'pop', 'post-teen pop'] 8658
# ['hip hop', 'rap'] 8659
# ['contemporary country', 'country', 'country dawn', 'country road'] 8660
# ['melodic rap', 'trap'] 8759
# ['cali rap', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 8760
# ['boy band', 'dance pop', 'pop', 'pop rock', 'post-teen pop'] 8901
# ['atl hip hop', 'pop rap', 'rap', 'trap'] 9028
# ['baton rouge rap', 'trap'] 9029
# ['electropop', 'pop'] 9158
# ['brostep', 'progressive electro house'] 9302
# ['hip hop', 'rap'] 9303
# ['alternative r&b', 'melodic rap'] 9304
# ['melodic rap', 'pop rap', 'rap', 'trap'] 9459
# ['k-pop', 'k-pop boy group'] 9460
# ['alternative r&b', 'pop'] 9655
# ['dance pop', 'pop', 'post-teen pop'] 9656
# ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'] 9657
# ['chicago rap', 'melodic rap'] 9814
# ['pop'] 10005
# ['melodic rap', 'rap', 'trap'] 10006
# ['contemporary country', 'country', 'country road', 'modern country rock'] 10191
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 10192
# ['dance pop', 'edm', 'house', 'pop', 'tropical house'] 10271
# ['contemporary country', 'country', 'country road', 'heartland rock', 'modern country rock', 'texas country'] 10639
# ['cali rap', 'pop', 'pop rap', 'trap queen'] 10640
# ['danish pop', 'pop', 'scandipop'] 10878
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 10879
# ['dance pop', 'edm', 'metropopolis', 'pop', 'post-teen pop', 'tropical house', 'uk pop'] 10880
# ['contemporary country', 'country', 'country road', 'modern country rock'] 10881
# ['atl hip hop', 'atl trap', 'gangster rap', 'melodic rap', 'pop rap', 'rap', 'trap'] 10882
# ['contemporary country', 'pop'] 10883
# ['dance pop', 'pop', 'post-teen pop'] 10884
# ['contemporary country', 'country', 'country dawn', 'dance pop', 'oklahoma country', 'pop', 'post-teen pop'] 11123
# ['country rap', 'lgbtq+ hip hop', 'pop rap'] 11124
# ['big room', 'edm', 'pop'] 11125
# ['la indie', 'pop', 'pop rap'] 11126
# ['dance pop', 'pop', 'pop rock', 'post-teen pop'] 11127
# ['canadian hip hop', 'melodic rap', 'pop rap', 'rap', 'toronto rap', 'trap'] 11128
# ['memphis hip hop'] 11129
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock', 'redneck'] 11361
# ['pop rap'] 11362
# ['post-teen pop', 'social media pop'] 11363
# ['atl hip hop', 'atl trap', 'gangster rap', 'melodic rap', 'pop rap', 'rap', 'trap'] 11364
# ['contemporary country', 'country', 'country road', 'modern country rock'] 11365
# ['melodic rap', 'rap', 'trap'] 11366
# ['hip hop', 'pop rap', 'rap'] 11618
# ['alternative r&b', 'hip hop', 'lgbtq+ hip hop', 'neo soul', 'pop'] 11619
# ['pop'] 11890
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 11891
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 11892
# ['dance pop', 'pop', 'post-teen pop'] 11893
# ['brostep', 'progressive electro house'] 13158
# ['contemporary country', 'country road'] 13159
# ['dance pop', 'pop', 'pop rap', 'r&b'] 13160
# ['contemporary country', 'country pop', 'country road', 'modern country rock'] 13161
# ['contemporary country', 'country road'] 13162
# ['contemporary country'] 13360
# ['contemporary country', 'country road', 'texas country'] 13361
# ['chicago rap', 'melodic rap'] 13362
# ['melodic rap', 'pop rap', 'rap', 'trap'] 13363
# ['pop', 'pop rap'] 13364
# ['alternative r&b', 'deep pop r&b', 'pop', 'pop rap', 'r&b', 'rap', 'rap latina'] 13365
# ['pop', 'pop rap'] 13619
# ['atl hip hop', 'atl trap', 'gangster rap', 'melodic rap', 'pop rap', 'rap', 'trap'] 13620
# ['atl hip hop', 'pop rap', 'rap', 'trap'] 13863
# ['adult standards', 'contemporary country', 'country', 'country road', 'modern country rock'] 13864
# ['alternative metal', 'alternative rock', 'art rock', 'nu metal', 'post-grunge', 'post-metal', 'progressive metal', 'progressive rock', 'rock'] 13865
# ['neo mellow', 'pop', 'pop rock', 'singer-songwriter'] 14154
# ['contemporary country', 'country', 'country road'] 14155
# ['contemporary country', 'country', 'country road', 'modern country rock'] 14156
# ['anthem worship', 'ccm', 'christian alternative rock', 'christian indie', 'christian music', 'world worship', 'worship'] 14157
# ['melodic rap', 'trap'] 14471
# ['contemporary country', 'pop'] 14472
# ['contemporary country', 'country road'] 14473
# ['bachata', 'latin', 'latin hip hop', 'latin pop', 'tropical'] 14474
# ['k-pop', 'k-pop boy group'] 14475
# ['latin', 'reggaeton', 'reggaeton flow', 'trap latino'] 14476
# ['contemporary country', 'country road'] 14477
# ['country rap'] 14631
# ['atl hip hop', 'atl trap', 'gangster rap', 'melodic rap', 'pop rap', 'rap', 'trap'] 14756
# ['dance pop', 'pop', 'post-teen pop'] 14787
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap'] 14826
# ['melodic rap'] 14842
# ['dance pop', 'pop', 'post-teen pop'] 14843
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap'] 14929
# ['emo rap', 'miami hip hop'] 14930
# ['dance pop', 'edm', 'pop', 'post-teen pop', 'scandipop', 'swedish electropop', 'swedish pop', 'tropical house'] 15013
# ['complextro', 'dance pop', 'edm', 'electro house', 'german techno', 'pop', 'post-teen pop', 'tropical house'] 15014
# ['pop reggaeton'] 15015
# ['baton rouge rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 15016
# ['alternative r&b', 'pop'] 15125
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 15126
# ['melodic rap', 'rap', 'trap'] 15127
# ['canadian hip hop', 'melodic rap', 'pop rap', 'rap', 'toronto rap', 'trap'] 15128
# ['la indie', 'pop', 'pop rap'] 15129
# ['atl hip hop', 'pop rap', 'rap', 'trap'] 15246
# ['hip hop', 'rap'] 15247
# ['contemporary country', 'country', 'country road', 'modern country rock'] 15248
# ['emo rap', 'miami hip hop'] 15372
# ['canadian hip hop', 'hip hop', 'melodic rap', 'pop rap', 'rap', 'southern hip hop', 'toronto rap', 'trap'] 15373
# ['cali rap', 'pop rap', 'rap', 'southern hip hop', 'trap'] 15374
# ['cali rap', 'trap'] 15375
# ['dance pop', 'pop', 'post-teen pop'] 15376
# ['detroit hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 15377
# ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 15518
# ['contemporary country', 'country pop'] 15519
# ['hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary'] 15520
# ['atl hip hop', 'hip hop', 'melodic rap', 'pop rap', 'rap', 'trap'] 15617
# ['country road'] 15618
# ['contemporary country', 'neo-traditional country', 'texas country'] 15724
# ['alternative r&b', 'pop', 'pop rap', 'rap'] 15725
# ['latin', 'puerto rican pop', 'reggaeton', 'trap latino'] 15726
# ['brostep', 'progressive electro house'] 15727
# ['alternative r&b', 'pop', 'pop rap'] 15728
# ['latin', 'reggaeton', 'trap latino'] 15840
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 15841
# ['alternative r&b', 'pop'] 15842
# ['melodic rap', 'pop rap', 'rap', 'trap'] 15959
# ['atl hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 15960
# ['dfw rap', 'rap', 'southern hip hop', 'trap'] 15961
# ['chicago rap', 'conscious hip hop', 'hip hop', 'pop rap', 'rap'] 15962
# ['atl hip hop', 'pop rap', 'rap', 'trap'] 16087
# ['pop', 'pop rap', 'tropical house'] 16088
# ['chicago rap', 'conscious hip hop', 'hip hop', 'pop rap', 'rap'] 16089
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap'] 16090
# ['florida rap'] 16091
# ['contemporary country'] 16370
# ['trap'] 16371
# ['melodic rap', 'rap', 'trap'] 16372
# ['hip hop', 'pop rap', 'rap'] 16648
# ['canadian hip hop', 'melodic rap', 'pop rap', 'rap', 'toronto rap', 'trap'] 16700
# ['nc hip hop', 'rap'] 16886
# ['contemporary country', 'country road'] 16901
# ['cali rap', 'trap'] 17137
# ['contemporary country', 'country pop', 'country road', 'modern country rock'] 17193
# ['pop', 'post-teen pop'] 17223
# ['contemporary country', 'pop', 'texas country'] 17524
# ['emo rap', 'lgbtq+ hip hop'] 17525
# ['baroque pop', 'emo', 'modern rock'] 17526
# ['dance pop', 'pop', 'post-teen pop'] 17527
# ['latin', 'reggaeton'] 17528
# ['electronic trap'] 17529
# ['canadian hip hop', 'pop'] 17805
# ['melodic rap'] 17806
# ['bronx hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'hip pop', 'pop rap', 'rap', 'trap'] 17807
# ['contemporary country', 'country road'] 18138
# ['j-pop', 'japanese singer-songwriter'] 18139
# ['contemporary country', 'country', 'country road', 'modern country rock'] 18140
# ['dance pop', 'pop', 'post-teen pop'] 18141
# ['contemporary country'] 18142
# ['latin', 'reggaeton'] 18143
# ['baroque pop', 'emo', 'modern rock'] 18144
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 18481
# ['contemporary country', 'country', 'country road', 'modern country rock'] 18482
# ['contemporary country', 'country', 'country road', 'oklahoma country'] 18483
# ['electropop', 'pop'] 18791
# ['miami hip hop', 'rap', 'trap', 'underground hip hop'] 18792
# ['atl hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 18793
# ['dance pop', 'pop', 'post-teen pop'] 18794
# ['escape room', 'minnesota hip hop', 'pop', 'pop rap', 'trap queen'] 18795
# ['contemporary country', 'country dawn', 'pop', 'texas country'] 18820
# ['dance pop', 'pop', 'pop rap', 'r&b'] 18821
# ['alternative r&b', 'hip hop', 'lgbtq+ hip hop', 'neo soul', 'pop'] 18822
# ['melodic rap', 'rap', 'trap'] 18823
# ['hip hop', 'melodic rap', 'rap', 'trap'] 18966
# ['pop', 'uk pop'] 18967
# ['hollywood', 'show tunes'] 18968
# ['dance pop', 'pop', 'post-teen pop'] 18969
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 19107
# ['panamanian pop', 'reggaeton'] 19108
# ['big room', 'edm', 'pop', 'progressive house', 'tropical house'] 19109
# ['melodic rap'] 19110
# ['baton rouge rap', 'trap'] 19111
# ['atl hip hop', 'dirty south rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 19112
# ['hawaiian hip hop', 'pop', 'rap'] 19113
# ['adult standards', 'cowboy western', 'oklahoma country', 'traditional country', 'yodeling'] 19139
# ['trap'] 19147
# ['deep pop r&b', 'melodic rap', 'pop rap', 'trap'] 19233
# ['dfw rap', 'melodic rap', 'rap'] 19245
# ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 19258
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 19274
# ['electropop', 'pop'] 19275
# ['nc hip hop', 'rap'] 19282
# ['pop'] 19311
# ['dance pop', 'pop', 'post-teen pop'] 19590
# ['dance pop', 'hip hop', 'miami hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 19628
# ['hip hop', 'rap'] 19858
# ['atl hip hop', 'atl trap', 'gangster rap', 'melodic rap', 'pop rap', 'rap', 'trap'] 19883
# ['hip hop', 'pop rap', 'rap'] 19953
# ['atl hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 20162
# ['contemporary country', 'country road', 'deep talent show'] 20165
# ['electropop', 'pop', 'tropical house'] 20217
# ['melodic rap', 'rap', 'trap'] 20239
# ['dance pop', 'hip hop', 'miami hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 20453
# ['electropop', 'pop'] 20455
# ['atl hip hop', 'hip hop', 'melodic rap', 'pop rap', 'rap', 'trap'] 20469
# ['atl hip hop', 'atl trap', 'pop rap', 'rap', 'trap'] 20523
# ['baton rouge rap', 'trap'] 20628
# ['hip hop', 'pop rap', 'rap'] 20657
# ['contemporary country', 'country', 'country road'] 20670
# ['melodic rap', 'rap', 'trap'] 20673
# ['nc hip hop', 'rap'] 20722
# ['electropop', 'pop'] 20923
# ['alternative r&b', 'pop', 'pop rap', 'r&b', 'urban contemporary'] 20953
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap'] 21004
# ['escape room', 'minnesota hip hop', 'pop', 'pop rap', 'trap queen'] 21007
# ['latin', 'reggaeton'] 21100
# ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'] 21214
# ['melodic rap', 'rap', 'trap'] 21218
# ['hip hop', 'rap'] 21230
# ['dance pop', 'electropop', 'indie poptimism', 'pop', 'post-teen pop', 'uk pop'] 21245
# ['cali rap'] 21261
# ['alternative r&b', 'pop'] 21292
# ['contemporary country'] 21324
# ['dance pop', 'pop', 'pop rap', 'tropical house'] 21325
# ['chicago rap', 'rap'] 21333
# ['cali rap'] 21348
# ['baton rouge rap', 'trap'] 21355
# ['latin', 'reggaeton', 'trap latino'] 21378
# ['nc hip hop', 'rap'] 21380
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 21388
# ['dance pop', 'pop', 'post-teen pop'] 21491
# ['chicago rap', 'rap'] 21635
# ['dance pop', 'pop', 'post-teen pop'] 21640
# ['contemporary country', 'country', 'country road'] 21668
# ['australian country', 'contemporary country', 'country', 'country road'] 21748
# ['dance pop', 'hip hop', 'miami hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap'] 21789
# ['contemporary country', 'country', 'country dawn', 'country pop', 'country road'] 21934
# ['contemporary country', 'country', 'country road'] 21969
# ['contemporary country', 'country', 'country road'] 21977

# %%
print(lista_generos[2000])
# Out:
# ['dance pop', 'pop', 'latin', 'latin pop', 'mexican pop', 'puerto rican pop', 'urban contemporary', 'country', 'r&b', 'crunk', 'dirty south rap', 'gangster rap', 'new orleans rap', 'girl group', 'hip pop', 'pop rap', 'neo mellow', 'pop rock', 'post-grunge', 'neo soul', 'contemporary country', 'country road', 'modern country rock', 'country dawn', 'album rock', 'art rock', 'classic rock', 'folk', 'folk rock', 'heartland rock', 'mellow gold', 'new wave pop', 'rock', 'roots rock', 'singer-songwriter', 'soft rock', 'yacht rock', 'tropical', 'alternative metal', 'funk metal', 'nu metal', 'rap metal', 'wrestling', 'europop', 'alternative r&b', 'escape room', 'indie r&b', 'indie soul', 'nc hip hop', 'deep pop r&b', 'rap', 'chicago rap', 'hip hop', 'new jack swing', 'acoustic pop', 'rap kreyol', 'arkansas country', 'country rock', 'deep latin christian', 'boy band', 'alternative rock', 'permanent wave', 'glam rock', 'piano rock', 'post-teen pop', 'east coast hip hop', 'queens hip hop', 'canadian pop', 'candy pop', 'norwegian pop', 'oklahoma country', 'hollywood', 'movie tunes', 'disco house', 'vocal house', 'pop punk', 'punk', 'socal pop punk', 'funk rock', 'southern hip hop', 'australian pop', 'canadian indie', 'canadian rock', 'comic', 'eurodance', 'grunge', 'industrial metal', 'industrial rock', 'rap rock', 'hardcore hip hop', 'atl hip hop', 'funk', 'soul', 'alternative hip hop', 'gospel', 'gospel r&b', 'electropop', 'hard rock', 'trap', 'quiet storm', 'miami hip hop', 'outlaw country', 'blues rock', 'reggae fusion', 'g funk', 'west coast rap', 'skate punk', 'alberta country', 'canadian contemporary country', 'canadian country', 'redneck', 'glam metal', 'grunge pop', 'dancehall', 'soca', 'deep southern trap', 'trap queen', 'modern salsa', 'salsa', 'bubblegum dance', 'metal', 'old school thrash', 'speed metal', 'thrash metal', 'french pop', 'operatic pop', 'bronx hip hop', 'philly rap', 'ccm', 'christian alternative rock', 'christian music', 'worship', 'conscious hip hop', 'rap latina', 'detroit hip hop', 'emo', 'old school hip hop', 'german techno', 'neo r&b', 'country rap', 'lgbtq+ hip hop', 'bahamian pop', 'harlem hip hop', 'minneapolis sound', 'australian country', 'bounce']

# %%
for i in range(len(lista_participacao[2000])):
    print(lista_participacao[2000][i][0],"\n",lista_participacao[2000][i][1])
# Out:
# CrybabyMariah Carey Featuring Snoop Dogg
#  Mariah Carey
# CrybabyMariah Carey Featuring Snoop Dogg
#  Snoop Dogg
# 4, 5, 6Sole Featuring JT Money & Kandi
#  Sole
# 4, 5, 6Sole Featuring JT Money & Kandi
#  JT Money
# 4, 5, 6Sole Featuring JT Money & Kandi
#  Kandi
# Best Of MeMya Featuring Jadakiss
#  Mya
# Best Of MeMya Featuring Jadakiss
#  Jadakiss
# Could I Have This Kiss ForeverWhitney Houston & Enrique Iglesias
#  Whitney Houston
# Could I Have This Kiss ForeverWhitney Houston & Enrique Iglesias
#  Enrique Iglesias
# 911Wyclef Jean Featuring Mary J. Blige
#  Wyclef Jean
# 911Wyclef Jean Featuring Mary J. Blige
#  Mary J. Blige
# Between Me And YouJa Rule Featuring Christina Milian
#  Ja Rule
# Between Me And YouJa Rule Featuring Christina Milian
#  Christina Milian
# Thank God I Found YouMariah Carey Featuring Joe & 98 Degrees
#  Mariah Carey
# Thank God I Found YouMariah Carey Featuring Joe & 98 Degrees
#  Joe
# Thank God I Found YouMariah Carey Featuring Joe & 98 Degrees
#  98 Degrees
# Big PimpinJay-Z Featuring UGK
#  Jay-Z
# Big PimpinJay-Z Featuring UGK
#  UGK
# Desert RoseSting Featuring Cheb Mami
#  Sting
# Desert RoseSting Featuring Cheb Mami
#  Cheb Mami
# Same Script, Different CastWhitney Houston & Deborah Cox
#  Whitney Houston
# Same Script, Different CastWhitney Houston & Deborah Cox
#  Deborah Cox
# Bad BoyzShyne Featuring Barrington Levy
#  Shyne
# Bad BoyzShyne Featuring Barrington Levy
#  Barrington Levy
# The Best Man I Can BeGinuwine, R.L., Tyrese, Case
#  Ginuwine
# The Best Man I Can BeGinuwine, R.L., Tyrese, Case
#  R.L.
# The Best Man I Can BeGinuwine, R.L., Tyrese, Case
#  Tyrese
# The Best Man I Can BeGinuwine, R.L., Tyrese, Case
#  Case
# Tha Block Is HotLil Wayne Featuring Juvenile & B.G.
#  Lil Wayne
# Tha Block Is HotLil Wayne Featuring Juvenile & B.G.
#  Juvenile
# Tha Block Is HotLil Wayne Featuring Juvenile & B.G.
#  B.G.
# Shut UpTrick Daddy Featuring Duece Poppito, Trina, Co
#  Trick Daddy
# Shut UpTrick Daddy Featuring Duece Poppito, Trina, Co
#  Duece Poppito
# Shut UpTrick Daddy Featuring Duece Poppito, Trina, Co
#  Trina
# Shut UpTrick Daddy Featuring Duece Poppito, Trina, Co
#  Co
# Maria MariaSantana Featuring The Product G&B
#  Santana
# Maria MariaSantana Featuring The Product G&B
#  The Product G&B
# It Wasnt MeShaggy Featuring Ricardo RikRok Ducent
#  Shaggy
# It Wasnt MeShaggy Featuring Ricardo RikRok Ducent
#  Ricardo RikRok Ducent
# Still D.R.E.Dr. Dre Featuring Snoop Dogg
#  Dr. Dre
# Still D.R.E.Dr. Dre Featuring Snoop Dogg
#  Snoop Dogg
# Private EmotionRicky Martin Featuring Meja
#  Ricky Martin
# Private EmotionRicky Martin Featuring Meja
#  Meja
# My First LoveAvant Featuring KeKe Wyatt
#  Avant
# My First LoveAvant Featuring KeKe Wyatt
#  KeKe Wyatt
# Girls Dem SugarBeenie Man Featuring Mya
#  Beenie Man
# Girls Dem SugarBeenie Man Featuring Mya
#  Mya
# Forgot About DreDr. Dre Featuring Eminem
#  Dr. Dre
# Forgot About DreDr. Dre Featuring Eminem
#  Eminem
# Feelin So GoodJennifer Lopez Featuring Big Pun & Fat Joe
#  Jennifer Lopez
# Feelin So GoodJennifer Lopez Featuring Big Pun & Fat Joe
#  Big Pun
# Feelin So GoodJennifer Lopez Featuring Big Pun & Fat Joe
#  Fat Joe
# How Many Licks?Lil Kim Featuring Sisqo
#  Lil Kim
# How Many Licks?Lil Kim Featuring Sisqo
#  Sisqo
# Love Sets You FreeKelly Price & Friends
#  Kelly Price
# Love Sets You FreeKelly Price & Friends
#  Friends
# Love Is BlindEve Featuring Faith Evans
#  Eve
# Love Is BlindEve Featuring Faith Evans
#  Faith Evans
# The Next EpisodeDr. Dre Featuring Snoop Dogg
#  Dr. Dre
# The Next EpisodeDr. Dre Featuring Snoop Dogg
#  Snoop Dogg
# Its So HardBig Punisher Featuring Donell Jones
#  Big Punisher
# Its So HardBig Punisher Featuring Donell Jones
#  Donell Jones
# Is That Your ChickMemphis Bleek Featuring Jay-Z & Missy Elliott
#  Memphis Bleek
# Is That Your ChickMemphis Bleek Featuring Jay-Z & Missy Elliott
#  Jay-Z
# Is That Your ChickMemphis Bleek Featuring Jay-Z & Missy Elliott
#  Missy Elliott
# Oh NoMos Def & Pharoahe Monch Featuring Nate Dogg
#  Mos Def
# Oh NoMos Def & Pharoahe Monch Featuring Nate Dogg
#  Pharoahe Monch
# Oh NoMos Def & Pharoahe Monch Featuring Nate Dogg
#  Nate Dogg
# Hey PapiJay-Z Featuring Memphis Bleek & Amil
#  Jay-Z
# Hey PapiJay-Z Featuring Memphis Bleek & Amil
#  Memphis Bleek
# Hey PapiJay-Z Featuring Memphis Bleek & Amil
#  Amil
# You Owe MeNAS Featuring Ginuwine
#  NAS
# You Owe MeNAS Featuring Ginuwine
#  Ginuwine
# Whats Your FantasyLudacris Featuring Shawnna
#  Ludacris
# Whats Your FantasyLudacris Featuring Shawnna
#  Shawnna
# Where You AreJessica Simpson Featuring Nick Lachey
#  Jessica Simpson
# Where You AreJessica Simpson Featuring Nick Lachey
#  Nick Lachey
# What You WantDMX Featuring Sisqo
#  DMX
# What You WantDMX Featuring Sisqo
#  Sisqo
# WhatChu LikeDa Brat Featuring Tyrese
#  Da Brat
# WhatChu LikeDa Brat Featuring Tyrese
#  Tyrese

# %% [markdown]
# ***Seção de Rede***

# %%
lista_cantores[2000]
# Out:
# ['Madonna',
#  'Ricky Martin',
#  'Debelah Morgan',
#  'Billy Gilman',
#  'Mariah Carey',
#  'Snoop Dogg',
#  'Mystikal',
#  'Destinys Child',
#  'matchbox twenty',
#  'Lucy Pearl',
#  'Phil Vassar',
#  'LeAnn Rimes',
#  'Don Henley',
#  'Enrique Iglesias',
#  'Mark Wills',
#  'Limp Bizkit',
#  'Robbie Williams',
#  'Sole',
#  'JT Money',
#  'Kandi',
#  'Mya',
#  'Jadakiss',
#  'Da Brat',
#  'Whitney Houston',
#  'Sister Hazel',
#  'Lonestar',
#  'Alan Jackson',
#  'Wyclef Jean',
#  'Mary J. Blige',
#  'Andy Griggs',
#  'Collin Raye',
#  'Son By Four',
#  'Backstreet Boys',
#  'No Doubt',
#  'Elton John',
#  'Christina Aguilera',
#  'Ja Rule',
#  'Christina Milian',
#  'Celine Dion',
#  'Nine Days',
#  'BBMak',
#  'M2M',
#  'Joe',
#  '98 Degrees',
#  'Rascal Flatts',
#  'Hoku',
#  'Toby Keith',
#  'Tim McGraw',
#  'Jo Dee Messina',
#  'Mandy Moore',
#  'Madison Avenue',
#  'Janet',
#  'Faith Hill',
#  'Blink-182',
#  'Red Hot Chili Peppers',
#  'Evan And Jaron',
#  'Jay-Z',
#  'UGK',
#  'Kid Rock',
#  'Savage Garden',
#  'Goo Goo Dolls',
#  'Mary Mary',
#  'Barenaked Ladies',
#  'Alice Deejay',
#  'Filter',
#  'Avant',
#  'DMX',
#  'Sting',
#  'Cheb Mami',
#  'TLC',
#  'Erykah Badu',
#  'Bloodhound Gang',
#  'Q-Tip',
#  'Deborah Cox',
#  'JAY-Z',
#  'Yolanda Adams',
#  'Aaron Carter',
#  'Patty Loveless',
#  'Shyne',
#  'Barrington Levy',
#  'Kelis',
#  'Ginuwine',
#  'R.L.',
#  'Tyrese',
#  'Case',
#  'Stone Temple Pilots',
#  'Third Eye Blind',
#  'Lil Wayne',
#  'Juvenile',
#  'B.G.',
#  'Carl Thomas',
#  'Changing Faces',
#  'Trick Daddy',
#  'Duece Poppito',
#  'Trina',
#  'Co',
#  'Kenny Chesney',
#  'Travis Tritt',
#  'Westlife',
#  'George Strait',
#  'Dixie Chicks',
#  'Santana',
#  'The Product G&B',
#  'O-Town',
#  'Jennifer Lopez',
#  'Pearl Jam',
#  'Profyle',
#  'OutKast',
#  'Shaggy',
#  'Ricardo RikRok Ducent',
#  'Public Announcement',
#  'Britney Spears',
#  'Dr. Dre',
#  'Clay Walker',
#  'The Wallflowers',
#  'The Offspring',
#  'Terri Clark',
#  'Meja',
#  'Gary Allan',
#  'Tracy Byrd',
#  'Kelly Price',
#  'Dave Hollister',
#  'Toni Braxton',
#  'LFO',
#  'Jessica Simpson',
#  'Bon Jovi',
#  'Macy Gray',
#  'Sugar Ray',
#  'Vertical Horizon',
#  'KeKe Wyatt',
#  'Splender',
#  'Nelly',
#  'Beenie Man',
#  'Aaron Tippin',
#  'Eminem',
#  'Papa Roach',
#  'Ruff Endz',
#  '3 Doors Down',
#  'Hot Boys',
#  'Jagged Edge',
#  'Gloria Estefan',
#  'Sisqo',
#  'Fuel',
#  'Lenny Kravitz',
#  'Martina McBride',
#  'Big Pun',
#  'Fat Joe',
#  'Lil Kim',
#  'Tracy Lawrence',
#  'Brian McKnight',
#  'Chante Moore',
#  'Nu Flavor',
#  'Vitamin C',
#  'Joe Diffie',
#  'Vince Gill',
#  'Marc Anthony',
#  '112',
#  'Lee Ann Womack',
#  'Aaliyah',
#  'Gerald Levert',
#  'Trace Adkins',
#  'Sammie',
#  'P!nk',
#  'Samantha Mumba',
#  'Metallica',
#  'Chely Wright',
#  'Brad Paisley',
#  'Reba McEntire',
#  'Musiq',
#  'Lara Fabian',
#  'Anastacia',
#  'Friends',
#  'Eve',
#  'Faith Evans',
#  'Eric Heatherly',
#  'NewSong',
#  '2Gether',
#  'Common',
#  'John Michael Montgomery',
#  'Trisha Yearwood',
#  'Garth Brooks',
#  'Montgomery Gentry',
#  'Tamia',
#  'Boyz II Men',
#  'En Vogue',
#  'Tracie Spencer',
#  'Ghostface Killah',
#  'Master P',
#  'Jamie ONeal',
#  'Hanson',
#  'SHeDAISY',
#  'Big Punisher',
#  'Donell Jones',
#  '3LW',
#  'Memphis Bleek',
#  'Missy Elliott',
#  'Mos Def',
#  'Pharoahe Monch',
#  'Nate Dogg',
#  'Tamar Braxton',
#  'Amil',
#  'Sunday',
#  'Will Smith',
#  'LL Cool J',
#  'Zombie Nation',
#  'Chris Cagle',
#  'Drama',
#  'Amel Larrieux',
#  'Ty Herndon',
#  'Everclear',
#  'Xzibit',
#  'Chad Brock',
#  'NAS',
#  'Billy Ray Cyrus',
#  'Brooks and Dunn',
#  'Ludacris',
#  'Shawnna',
#  'Darryl Worley',
#  'Nick Lachey',
#  'Ying Yang Twins',
#  'Baha Men',
#  'Black Rob',
#  'Next',
#  'Creed',
#  '504 Boyz',
#  'Keith Urban',
#  'Lou Bega',
#  'DAngelo',
#  'Camron']

# %%
for ano in range(2000,2020):
    basename="base{}.gml".format(ano)
    with open(basename,"w") as content:
        content.writelines("graph [\n  directed 1\n")
        for i in range(len(lista_cantores[ano])):
            line="  node [\n    id \"{}\"\n  ]\n".format(lista_cantores[ano][i])
            content.writelines(line)
        for i in range(len(lista_musicas[ano])):
            line="  node [\n    id \"{}\"\n  ]\n".format(lista_musicas[ano][i])
            content.writelines(line)
        for i in range(len(lista_participacao[ano])):
            line="  edge [\n    source \"{0}\"\n    target \"{1}\"\n    weight {2}\n  ]\n".format(lista_participacao[ano][i][0],lista_participacao[ano][i][1],1)
            content.writelines(line)
        content.writelines("]")

# %%
import seaborn as sns

import networkx as nx

import freeman as fm

import operator

from statistics import mean

# %%
def get_sorted_list_from_dict(dic):
    dic_f = sorted(dic.items(), key=operator.itemgetter(1))
    ckeys=range(len(dic_f))
    keys=[]
    values=[]
    for i in dic_f:
        keys.append(i[0])
        values.append(i[1])
    return ckeys, keys, values

# %%
def eigen(T,row):
    return T[row["SongFiltred"]]

# %%
for ano in range(2000,2020):
    basename="base{}.gml".format(ano)
    g = fm.load(basename)

    g.label_nodes()
    g.set_all_nodes(size=1, labpos='hover')
    g.set_all_edges(color=(0, 0, 0, 0.5))
    t1,t2 = nx.hits(g, max_iter=100000, tol=1e-06, nstart=None, normalized=True)
    
    df=dic_dataframe[ano].copy()
    df.apply (lambda t1, row: eigen(t1,row), axis=1)
    
    bc_ck,bc_k,bc_v=get_sorted_list_from_dict(t1)
    sns.scatterplot(bc_ck, bc_v);
    plt.show()

    print("média: {}".format(mean(bc_v)))
    print("Atores mais importantes:")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-9b4278d159d7> in <module>
#       9
#      10     df=dic_dataframe[ano].copy()
# ---> 11     df.apply (lambda t1,row: eigen(t1,row), axis=1)
#      12
#      13     bc_ck,bc_k,bc_v=get_sorted_list_from_dict(t1)
#
# c:\users\rodri\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7543             kwds=kwds,
#    7544         )
# -> 7545         return op.get_result()
#    7546
#    7547     def applymap(self, func) -> "DataFrame":
#
# c:\users\rodri\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# c:\users\rodri\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# --> 255         results, res_index = self.apply_series_generator()
#     256
#     257         # wrap results
#
# c:\users\rodri\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     282                 for i, v in enumerate(series_gen):
#     283                     # ignore SettingWithCopy here in case the user mutates
# --> 284                     results[i] = self.f(v)
#     285                     if isinstance(results[i], ABCSeries):
#     286                         # If we have a view on v, we need to make a copy because
#
# TypeError: <lambda>() missing 1 required positional argument: 'row'

# %%
for ano in range(2000,2020):
    genre="genre{}.gml".format(ano)
    with open(genre,"w") as content:
        content.writelines("graph [\n  directed 1\n")
        for i in range(len(lista_generos[ano])):
            line="  node [\n    id \"{}\"\n  ]\n".format(lista_generos[ano][i])
            content.writelines(line)
        for i in range(len(lista_musicas[ano])):
            line="  node [\n    id \"{}\"\n  ]\n".format(lista_musicas[ano][i])
            content.writelines(line)
        for i in range(len(lista_musicas_generos[ano])):
            line="  edge [\n    source \"{0}\"\n    target \"{1}\"\n    weight {2}\n  ]\n".format(lista_musicas_generos[ano][i][0],lista_musicas_generos[ano][i][1],1)
            content.writelines(line)
            line="  edge [\n    source \"{0}\"\n    target \"{1}\"\n    weight {2}\n  ]\n".format(lista_musicas_generos[ano][i][1],lista_musicas_generos[ano][i][0],1)
            content.writelines(line)
        content.writelines("]")

# %%
for ano in range(2000,2020):
    genre="genre{}.gml".format(ano)
    g = fm.load(genre)

    g.label_nodes()
    g.set_all_nodes(size=1, labpos='hover')
    g.set_all_edges(color=(0, 0, 0, 0.5))
    t1,t2 = nx.hits(g, max_iter=100000, tol=1e-06, nstart=None, normalized=True)
    

    
    bc_ck,bc_k,bc_v=get_sorted_list_from_dict(t1)
    
    sns.scatterplot(bc_ck, bc_v);
    plt.show()

    print("média: {}".format(mean(bc_v)))
    print("Atores mais importantes:")
# Out:
# média: 0.002403846153846154
# Atores mais importantes:
# média: 0.0024813895781637726
# Atores mais importantes:
# média: 0.0024096385542168677
# Atores mais importantes:
# média: 0.002192982456140351
# Atores mais importantes:
# média: 0.0022271714922048997
# Atores mais importantes:
# média: 0.0019607843137254915
# Atores mais importantes:
# média: 0.0019083969465648852
# Atores mais importantes:
# média: 0.0021881838074398288
# Atores mais importantes:
# média: 0.0019047619047619043
# Atores mais importantes:
# média: 0.0018691588785046689
# Atores mais importantes:
# média: 0.0017482517482517487
# Atores mais importantes:
# média: 0.0016313213703099505
# Atores mais importantes:
# média: 0.0020449897750511228
# Atores mais importantes:
# média: 0.0019801980198019785
# Atores mais importantes:
# média: 0.001930501930501931
# Atores mais importantes:
# média: 0.0019011406844106449
# Atores mais importantes:
# média: 0.0018148820326678746
# Atores mais importantes:
# média: 0.0017605633802816887
# Atores mais importantes:
# média: 0.0014388489208633096
# Atores mais importantes:
# média: 0.0015337423312883445
# Atores mais importantes:

# %%
h = fm.load('genre2000.gml')

h.label_nodes()
h.set_all_nodes(size=1, labpos='hover')
h.set_all_edges(color=(0, 0, 0, 0.5))

h.interact()
# Out:
#         <iframe
#             width="810"
#             height="460"
#             src="__fmcache__\336010504.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ***Seção de Métrica***

# %%
lista_generos.keys()
# Out:
# dict_keys([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %% [markdown]
# ***Seção de Teste de Hipótese***

# %%
def eigen(row):
    return t1[row["SongFiltred"]]

# %%
data2000['eigen']=data2000.apply (lambda row: eigen(row), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-acb2aed15229> in <module>
# ----> 1 data2000['eigen']=data2000.apply (lambda row: eigen(row), axis=1)
#
# NameError: name 'data2000' is not defined

# %%
model = sm.OLS(data2000['loginv'], data2000[['eigen','danceability',
       'energy', 'loudness', 'speechiness', 'acousticness']])
result = model.fit()
result.summary()

# %%
dataeigen = data2000.sort_values(by=['eigen'])

# %%
lista_generos=[]
for i in data2000.index:
    
    gen= conv_string_to_list(data2000["spotify_genre"][i])
    
    for j in range(len(gen)):
        if gen[j] not in lista_generos:
            lista_generos.append(gen[j])
            
lista_musicas_generos=[]

for i in data2000.index:
    insertfeat(lista_musicas_generos,gen,data2000["SongFiltred"][i])

# %%
u1 = nx.betweenness_centrality(h)
bc_ck,bc_k,bc_v=get_sorted_list_from_dict(u1)
sns.scatterplot(bc_ck, bc_v);

print("média: {}".format(mean(bc_v)))
print("Atores mais importantes:")

# %%
# def plotcalor(nome):
#     xv=7
#     yv=6
#     dx=max(dataeigen["eigen"])/xv
#     dy=max(dataeigen[nome])/yv
    
#     heatmap=np.array([[0.0]*xv]*xv)
#     for i in range(xv):
#         cat=0
        
#         lista=[0]*xv
#         for j in dataeigen.index:
#             if (dataeigen["eigen"][j]<(dx*i+dx) and dataeigen["eigen"][j]>(dx*i)):
#                 cat+=1 
        
#         for j in dataeigen.index:
#             for k in range(xv):
#                 if (dataeigen["eigen"][j]<=(dx*i+dx) and dataeigen["eigen"][j]>(dx*i)):
#                     if (dataeigen[nome][j]<=(dy*k+dy) and dataeigen[nome][j]>(dy*k)):
#                         lista[k]+=1/cat
#         for j in range(len(lista)):
            
#             heatmap[xv-j-1][i]=lista[j]
            
#     print(heatmap)
#     fig, ax = plt.subplots()
#     im = ax.imshow(heatmap)
#     fig.tight_layout()
#     plt.show()

# %%
from statistics import mean

import seaborn as sns
import networkx as nx

import pandas as pd
import time
import datetime

# %%
data = pd.read_csv('bill/hotStuff.csv')

# %%
data2 = pd.read_excel('bill/hot100.xlsx')

# %%
data2.head(9630)
# Out:
#                                                  SongID  \
# 0                         AdictoTainy, Anuel AA & Ozuna
# 1     The Ones That Didn't Make It Back HomeJustin M...
# 2                     ShallowLady Gaga & Bradley Cooper
# 3                   EnemiesPost Malone Featuring DaBaby
# 4       Bacc At It AgainYella Beezy, Gucci Mane & Quavo
# ...                                                 ...
# 9625                          I'll Be GoodRene & Angela
# 9626                 Legend In Your Own TimeCarly Simon
# 9627                      Just Another DayQueen Latifah
# 9628                It's Money That MattersRandy Newman
# 9629                It's AlrightMemphis Bleek (& Jay-Z)
#
#                             Performer                                    Song  \
# 0             Tainy, Anuel AA & Ozuna                                  Adicto
# 1                        Justin Moore  The Ones That Didn't Make It Back Home
# 2          Lady Gaga & Bradley Cooper                                 Shallow
# 3        Post Malone Featuring DaBaby                                 Enemies
# 4     Yella Beezy, Gucci Mane & Quavo                        Bacc At It Again
# ...                               ...                                     ...
# 9625                    Rene & Angela                            I'll Be Good
# 9626                      Carly Simon                 Legend In Your Own Time
# 9627                    Queen Latifah                        Just Another Day
# 9628                     Randy Newman                 It's Money That Matters
# 9629          Memphis Bleek (& Jay-Z)                            It's Alright
#
#                                           spotify_genre  \
# 0                                     ['pop reggaeton']
# 1     ['arkansas country', 'contemporary country', '...
# 2                                  ['dance pop', 'pop']
# 3                     ['dfw rap', 'melodic rap', 'rap']
# 4        ['dfw rap', 'rap', 'southern hip hop', 'trap']
# ...                                                 ...
# 9625  ['banda', 'grupera', 'norteno', 'regional mexi...
# 9626  ['adult standards', 'classic uk pop', 'folk', ...
# 9627  ['conscious hip hop', 'east coast hip hop', 'h...
# 9628     ['disney', 'movie tunes', 'singer-songwriter']
# 9629  ['east coast hip hop', 'gangster rap', 'hardco...
#
#             spotify_track_id  \
# 0     3jbT1Y5MoPwEIpZndDDwVq
# 1                        NaN
# 2     2VxeLyX666F8uXCJ0dZF8B
# 3     0Xek5rqai2jcOWCYWJfVCF
# 4     2biNa12dMbHJrHVFRt8JyO
# ...                      ...
# 9625  2SPNs07BKygbkbf48KNFEQ
# 9626  7fA9fAzkCyBQ8Ln2a7MK81
# 9627  48FC4RXepyOHJFTyFuQkm0
# 9628  5gUQPTljjDnEkpYPZ3ZvAP
# 9629  1SKhE8yTMuGrTLte0os673
#
#                               spotify_track_preview_url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     https://p.scdn.co/mp3-preview/fa6fa6f6f363be29...
# ...                                                 ...
# 9625                                                NaN
# 9626  https://p.scdn.co/mp3-preview/1ce86a7f5891035e...
# 9627                                                NaN
# 9628  https://p.scdn.co/mp3-preview/59586730cebaf431...
# 9629                                                NaN
#
#                           spotify_track_album  spotify_track_explicit  \
# 0              Adicto (with Anuel AA & Ozuna)                     0.0
# 1                                         NaN                     NaN
# 2                   A Star Is Born Soundtrack                     0.0
# 3                        Hollywood's Bleeding                     1.0
# 4                            Bacc At It Again                     1.0
# ...                                       ...                     ...
# 9625  Street Called Desire (Expanded Edition)                     0.0
# 9626                  The Best Of Carly Simon                     0.0
# 9627                              Black Reign                     0.0
# 9628                           Land Of Dreams                     0.0
# 9629                Vol.2 ... Hard Knock Life                     1.0
#
#       spotify_track_duration_ms  spotify_track_popularity  ...   key  \
# 0                      270740.0                      91.0  ...  10.0
# 1                           NaN                       NaN  ...   NaN
# 2                      215733.0                      88.0  ...   7.0
# 3                      196760.0                      86.0  ...   6.0
# 4                      228185.0                      61.0  ...   8.0
# ...                         ...                       ...  ...   ...
# 9625                   321066.0                      54.0  ...  10.0
# 9626                   221253.0                      30.0  ...   9.0
# 9627                   268066.0                      35.0  ...   7.0
# 9628                   247800.0                      24.0  ...   2.0
# 9629                   241733.0                      47.0  ...   5.0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -4.803   0.0       0.0735       0.01700          0.000016    0.1790
# 1          NaN   NaN          NaN           NaN               NaN       NaN
# 2       -6.362   1.0       0.0308       0.37100          0.000000    0.2310
# 3       -4.169   1.0       0.2100       0.05880          0.000000    0.0955
# 4       -5.725   0.0       0.1680       0.00124          0.000001    0.0716
# ...        ...   ...          ...           ...               ...       ...
# 9625    -9.784   1.0       0.0546       0.11800          0.000048    0.0733
# 9626    -7.689   0.0       0.0264       0.81600          0.000000    0.1480
# 9627   -18.494   1.0       0.3270       0.37600          0.078200    0.2080
# 9628   -13.247   1.0       0.0298       0.04850          0.004060    0.0660
# 9629    -9.155   0.0       0.2220       0.02200          0.000000    0.2470
#
#       valence    tempo  time_signature
# 0       0.623   80.002             4.0
# 1         NaN      NaN             NaN
# 2       0.323   95.799             4.0
# 3       0.667   76.388             4.0
# 4       0.856  135.979             4.0
# ...       ...      ...             ...
# 9625    0.757  108.392             4.0
# 9626    0.495  102.667             4.0
# 9627    0.284  173.868             4.0
# 9628    0.757  124.648             4.0
# 9629    0.799   95.379             4.0
#
# [9630 rows x 22 columns]

# %%
l=[]
for i in range(len(data2["Performer"])):
    
    l.append(data2["Performer"][i]) 
print(l)
# Out:
# ['Tainy, Anuel AA & Ozuna', 'Justin Moore', 'Lady Gaga & Bradley Cooper', 'Post Malone Featuring DaBaby', 'Yella Beezy, Gucci Mane & Quavo', 'Taylor Swift', 'DaBaby', 'NF', 'Post Malone', 'Brantley Gilbert + Lindsay Ell', 'NLE Choppa', 'Taylor Swift', 'Chris Brown Featuring Gunna', 'Nicky Jam X Ozuna', 'Ant Saunders', 'BTS Featuring Lauv', 'NF', 'Rod Wave & Kevin Gates', 'Roddy Ricch Featuring Meek Mill', 'DaBaby', 'Chris Brown Featuring Justin Bieber & Ink', 'Tones And I', 'The Weeknd', 'Ariana Grande', 'DaBaby Featuring Chance The Rapper, Gucci Mane & YK Osiris', 'Taylor Swift', 'Matt Stell', 'Harry Styles', 'Young Thug Featuring Lil Baby', 'Young Thug Featuring Lil Baby', 'Harry Styles', 'Summer Walker', 'Luke Combs', 'The Chainsmokers & Illenium Featuring Lennon Stella', 'Dierks Bentley', 'Internet Money, Lil Tecca & A Boogie Wit da Hoodie', 'NAV Featuring Meek Mill', 'Ellie Goulding & Juice WRLD', 'Taylor Swift', '24kGoldn', 'The Black Eyed Peas X J Balvin', 'Diplo Presents Thomas Wesley Featuring Morgan Wallen', 'SHAED', 'Blake Shelton', 'Halsey', '5 Seconds Of Summer', 'Chance The Rapper Featuring MadeinTYO & DaBaby', 'J Balvin & Bad Bunny', 'Harry Styles', 'Travis Scott', 'Niall Horan', 'Young Thug', 'Mariah Carey', 'Shawn Mendes & Camila Cabello', 'Post Malone', 'Lil Baby & DaBaby', 'DaBaby Featuring Lil Baby & Moneybagg Yo', 'Drake', 'Drake', 'J Balvin & Bad Bunny', 'Bryce Vine Featuring YG', 'Sam Smith', 'Taylor Swift', 'Dreamville Featuring Bas, JID, Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God', 'The Ronettes', 'Brenda Lee', 'YoungBoy Never Broke Again', 'Lana Del Rey', 'Post Malone', 'Juice WRLD', 'Drake', 'Dua Lipa', 'Kanye West', 'Chris Lane', 'Blanco Brown', 'French Montana Featuring Post Malone, Cardi B & Rvssian', 'Post Malone', 'A Boogie Wit da Hoodie', 'NLE Choppa', 'Halsey', 'Luke Combs', 'DaBaby Featuring Kevin Gates', 'Florida Georgia Line', 'Kane Brown', 'Megan Thee Stallion Featuring DaBaby', 'Young Thug Featuring Future', 'Trippie Redd', 'Chance The Rapper Featuring John Legend', 'DaBaby', 'Ali Gatie', 'Marshmello & Kane Brown', 'Kanye West Featuring Fred Hammond', 'Maren Morris', 'Drake', 'XXXTENTACION Featuring PnB Rock & Trippie Redd', 'Wale Featuring Jeremih', 'Lil Uzi Vert', 'YoungBoy Never Broke Again', 'Tyler, The Creator', 'Old Dominion', 'Nicki Minaj', 'Nipsey Hussle Featuring Roddy Ricch & Hit-Boy', 'Burl Ives', 'Bad Bunny & Tainy', 'Travis Scott', 'Chance The Rapper Featuring Death Cab For Cutie', 'Gene Autry', 'Morgan Wallen', 'Keith Urban', 'blackbear', 'DaBaby', 'Camila Cabello', 'Trippie Redd Featuring YoungBoy Never Broke Again', 'Taylor Swift', 'DaBaby Featuring Stunna 4 Vegas', 'Billie Eilish', 'Doja Cat & Tyga', 'Young Thug', 'Young Thug', 'Billie Eilish', 'Eli Young Band', 'Lizzo', 'Post Malone', 'Sarah Jeffery', 'Normani', 'Khalid Featuring A Boogie Wit da Hoodie', 'Ariana Grande', 'Dove Cameron, Sofia Carson, Booboo Stewart, Cameron Boyce, Thomas Doherty, China Anne McClain & Dylan Playfair', 'Young Thug, J. Cole & Travis Scott', 'Marshmello & Bastille', 'Trippie Redd', 'Kelsea Ballerini', 'Offset Featuring Cardi B', 'Luke Bryan', 'Katy Perry', 'Bobby Helms', 'Jason Aldean', 'Doja Cat', 'Khalid', 'Harry Styles', 'Cardi B & Bruno Mars', 'Taylor Swift', 'DaniLeigh Featuring Chris Brown', 'Panic! At The Disco', 'YK Osiris', 'Beyonce, SAINt JHN & Wizkid Featuring Blue Ivy Carter', 'DaBaby', 'Meek Mill Featuring Ella Mai', 'Young Thug Featuring Lil Uzi Vert', 'Don Toliver', 'Rod Wave', 'Ariana Grande & Social House', 'Beyonce', 'Anuel AA, Daddy Yankee, Karol G, Ozuna & J Balvin', 'Lunay, Daddy Yankee & Bad Bunny', 'Lil Tecca', 'Lil Tecca', 'Post Malone Featuring Future & Halsey', 'Miranda Lambert', 'Kevin Gates', 'Eric Church', 'Trevor Daniel', 'YNW Melly', 'P!nk', 'Dan + Shay', 'Ed Sheeran Featuring Camila Cabello & Cardi B', 'benny blanco, Halsey & Khalid', 'Kanye West', 'Kanye West', 'Tool', '21 Savage', 'Ed Sheeran Featuring Khalid', 'The Cha ...

# %%
s="juao e mateus"
f="juao"
if f in s:
    print("oi")
# Out:
# oi

# %%
import re

dic_bugs={
    "Lil Nas &":"Lil Nas X",
    "& Ambassadors":"X Ambassadors",
    "Mia &":"Mia X"
    
}

feat="Featuring"
def parse(nomes):
    
    new_nomes=nomes.replace("(","")
    new_nomes=new_nomes.replace(")","")
    new_nomes=new_nomes.replace("[","")
    new_nomes=new_nomes.replace("]","")
    new_nomes=new_nomes.replace("Featuring","&")
    new_nomes=new_nomes.replace("Feat.","&")
    new_nomes=new_nomes.replace(" X "," & ")
    new_nomes=new_nomes.replace(" x "," & ")
    for i in dic_bugs:
        if i in new_nomes:
            new_nomes=new_nomes.replace(i,dic_bugs[i])
    return re.split(r'\s[,&+]\s', new_nomes)
    
    
print(parse("Lil Nas X Featuring Billy Ray Cyrus"))
# Out:
# ['Lil Nas X', 'Billy Ray Cyrus']

# %%
def createmultifeat(lista):
    final=[]
    for i in range(len(lista)):
        for j in range(i+1,len(lista)):
            final.append([lista[i],lista[j]])
    return final
print (createmultifeat(['NAV', 'Meek Mill']))
# Out:
# [['NAV', 'Meek Mill']]

# %%
def insertfeat(dic,lista):
    for i in range(len(lista)):
        change=0
        for j in dic:
            if (dic[j]["first"]==lista[i][0] and dic[j]["second"]==lista[i][1]) or (dic[j]["second"]==lista[i][0] and dic[j]["first"]==lista[i][1]):
                dic[j]["weight"]+=1
                change=1
        if (change==0):
            dic[len(dic)]={"first":lista[i][0],"second":lista[i][1],"weight":1}
        

test={0:{"first":'NAV',"second":"Meek","weight":1}}
l=[['Meek Mill','NAV']]
insertfeat(test, l)
print(test)
# Out:
# {0: {'first': 'NAV', 'second': 'Meek', 'weight': 1}, 1: {'first': 'Meek Mill', 'second': 'NAV', 'weight': 1}}

# %%
a={}
print(len(a))
# Out:
# 0

# %%
lista_cantores=[]
dic_feat={}
s=0
for i in range(len(data2["Performer"])):
    lista_singers = parse(data2["Performer"][i])
    for j in lista_singers:
        if j not in lista_cantores:
            lista_cantores.append(j)
    if len(lista_singers)>1:
        ligacoes=createmultifeat(lista_singers)
        insertfeat(dic_feat,ligacoes)

# %%
lista_cantores.sort()
print(dic_feat)
# Out:
# {0: {'first': 'Tainy, Anuel AA', 'second': 'Ozuna', 'weight': 1}, 1: {'first': 'Lady Gaga', 'second': 'Bradley Cooper', 'weight': 2}, 2: {'first': 'Post Malone', 'second': 'DaBaby', 'weight': 1}, 3: {'first': 'Yella Beezy, Gucci Mane', 'second': 'Quavo', 'weight': 2}, 4: {'first': 'Brantley Gilbert', 'second': 'Lindsay Ell', 'weight': 1}, 5: {'first': 'Chris Brown', 'second': 'Gunna', 'weight': 1}, 6: {'first': 'Nicky Jam', 'second': 'Ozuna', 'weight': 2}, 7: {'first': 'BTS', 'second': 'Lauv', 'weight': 1}, 8: {'first': 'Rod Wave', 'second': 'Kevin Gates', 'weight': 1}, 9: {'first': 'Roddy Ricch', 'second': 'Meek Mill', 'weight': 1}, 10: {'first': 'Chris Brown', 'second': 'Justin Bieber', 'weight': 2}, 11: {'first': 'Chris Brown', 'second': 'Ink', 'weight': 1}, 12: {'first': 'Justin Bieber', 'second': 'Ink', 'weight': 1}, 13: {'first': 'DaBaby', 'second': 'Chance The Rapper, Gucci Mane', 'weight': 1}, 14: {'first': 'DaBaby', 'second': 'YK Osiris', 'weight': 1}, 15: {'first': 'Chance The Rapper, Gucci Mane', 'second': 'YK Osiris', 'weight': 1}, 16: {'first': 'Young Thug', 'second': 'Lil Baby', 'weight': 3}, 17: {'first': 'The Chainsmokers', 'second': 'Illenium', 'weight': 1}, 18: {'first': 'The Chainsmokers', 'second': 'Lennon Stella', 'weight': 1}, 19: {'first': 'Illenium', 'second': 'Lennon Stella', 'weight': 1}, 20: {'first': 'Internet Money, Lil Tecca', 'second': 'A Boogie Wit da Hoodie', 'weight': 1}, 21: {'first': 'NAV', 'second': 'Meek Mill', 'weight': 2}, 22: {'first': 'Ellie Goulding', 'second': 'Juice WRLD', 'weight': 1}, 23: {'first': 'The Black Eyed Peas', 'second': 'J Balvin', 'weight': 1}, 24: {'first': 'Diplo Presents Thomas Wesley', 'second': 'Morgan Wallen', 'weight': 1}, 25: {'first': 'Chance The Rapper', 'second': 'MadeinTYO', 'weight': 1}, 26: {'first': 'Chance The Rapper', 'second': 'DaBaby', 'weight': 1}, 27: {'first': 'MadeinTYO', 'second': 'DaBaby', 'weight': 1}, 28: {'first': 'J Balvin', 'second': 'Bad Bunny', 'weight': 2}, 29: {'first': 'Shawn Mendes', 'second': 'Camila Cabello', 'weight': 2}, 30: {'first': 'Lil Baby', 'second': 'DaBaby', 'weight': 2}, 31: {'first': 'DaBaby', 'second': 'Moneybagg Yo', 'weight': 1}, 32: {'first': 'Lil Baby', 'second': 'Moneybagg Yo', 'weight': 1}, 33: {'first': 'Bryce Vine', 'second': 'YG', 'weight': 2}, 34: {'first': 'Dreamville', 'second': 'Bas, JID, Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy', 'weight': 1}, 35: {'first': 'Dreamville', 'second': 'Ski Mask The Slump God', 'weight': 1}, 36: {'first': 'Bas, JID, Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy', 'second': 'Ski Mask The Slump God', 'weight': 1}, 37: {'first': 'French Montana', 'second': 'Post Malone, Cardi B', 'weight': 1}, 38: {'first': 'French Montana', 'second': 'Rvssian', 'weight': 1}, 39: {'first': 'Post Malone, Cardi B', 'second': 'Rvssian', 'weight': 1}, 40: {'first': 'DaBaby', 'second': 'Kevin Gates', 'weight': 1}, 41: {'first': 'Megan Thee Stallion', 'second': 'DaBaby', 'weight': 1}, 42: {'first': 'Young Thug', 'second': 'Future', 'weight': 7}, 43: {'first': 'Chance The Rapper', 'second': 'John Legend', 'weight': 1}, 44: {'first': 'Marshmello', 'second': 'Kane Brown', 'weight': 1}, 45: {'first': 'Kanye West', 'second': 'Fred Hammond', 'weight': 1}, 46: {'first': 'XXXTENTACION', 'second': 'PnB Rock', 'weight': 2}, 47: {'first': 'XXXTENTACION', 'second': 'Trippie Redd', 'weight': 1}, 48: {'first': 'PnB Rock', 'second': 'Trippie Redd', 'weight': 1}, 49: {'first': 'Wale', 'second': 'Jeremih', 'weight': 3}, 50: {'first': 'Nipsey Hussle', 'second': 'Roddy Ricch', 'weight': 2}, 51: {'first': 'Nipsey Hussle', 'second': 'Hit-Boy', 'weight': 2}, 52: {'first': 'Roddy Ricch', 'second': 'Hit-Boy', 'weight': 2}, 53: {'first': 'Bad Bunny', 'second': 'Tainy', 'weight': 2}, 54: {'first': 'Chance The Rapper', 'second': 'Death Cab For Cutie', 'weight': 1}, 55: {'first': 'Trippie Redd', 'second': 'YoungBoy Never Broke Again', 'weight': 1}, 56: {'first': 'DaBaby', 'second': 'Stunna 4 Vegas', ' ...

# %%
def ano(row):
   return int(row["WeekID"][-4:])

# %%
data['ANO'] = data.apply (lambda row: ano(row), axis=1)

# %%
dataPBANO=data[data["ANO"]>=2000]

# %%
dataPBANO[dataPBANO["Song"]=="Radioactive"].head(400)
# Out:
#                                                       url      WeekID  \
# 1133    http://www.billboard.com/charts/hot-100/2010-1...   10/2/2010
# 2642    http://www.billboard.com/charts/hot-100/2012-1...   12/8/2012
# 2871    http://www.billboard.com/charts/hot-100/2012-1...  12/15/2012
# 5679    http://www.billboard.com/charts/hot-100/2012-1...  12/22/2012
# 5869    http://www.billboard.com/charts/hot-100/2012-1...  12/29/2012
# ...                                                   ...         ...
# 81484   http://www.billboard.com/charts/hot-100/2012-1...  11/17/2012
# 81732   http://www.billboard.com/charts/hot-100/2012-1...  11/24/2012
# 81958   http://www.billboard.com/charts/hot-100/2012-1...   12/1/2012
# 164721  http://www.billboard.com/charts/hot-100/2010-1...   10/9/2010
# 165241  http://www.billboard.com/charts/hot-100/2012-0...   8/25/2012
#
#         Week Position         Song        Performer  \
# 1133               37  Radioactive    Kings Of Leon
# 2642               76  Radioactive  Imagine Dragons
# 2871               72  Radioactive  Imagine Dragons
# 5679               65  Radioactive  Imagine Dragons
# 5869               55  Radioactive  Imagine Dragons
# ...               ...          ...              ...
# 81484              87  Radioactive  Imagine Dragons
# 81732              83  Radioactive  Imagine Dragons
# 81958              71  Radioactive  Imagine Dragons
# 164721             95  Radioactive    Kings Of Leon
# 165241             98  Radioactive  Imagine Dragons
#
#                             SongID  Instance  Previous Week Position  \
# 1133      RadioactiveKings Of Leon         1                     NaN
# 2642    RadioactiveImagine Dragons         2                    71.0
# 2871    RadioactiveImagine Dragons         2                    76.0
# 5679    RadioactiveImagine Dragons         2                    72.0
# 5869    RadioactiveImagine Dragons         2                    65.0
# ...                            ...       ...                     ...
# 81484   RadioactiveImagine Dragons         2                    90.0
# 81732   RadioactiveImagine Dragons         2                    87.0
# 81958   RadioactiveImagine Dragons         2                    83.0
# 164721    RadioactiveKings Of Leon         1                    37.0
# 165241  RadioactiveImagine Dragons         1                    93.0
#
#         Peak Position  Weeks on Chart   ANO
# 1133               37               1  2010
# 2642               71              13  2012
# 2871               71              14  2012
# 5679               65              15  2012
# 5869               55              16  2012
# ...               ...             ...   ...
# 81484              87              10  2012
# 81732              83              11  2012
# 81958              71              12  2012
# 164721             37               2  2010
# 165241             93               2  2012
#
# [92 rows x 11 columns]

# %%
graph [
  directed 1
  node [
    id "abelcan"
  ]
  node [
    id "andreew"
  ] 
  edge [
    source "ericfoa"
    target "abelcan"
    weight 1
  ]
  edge [
    source "joaopmjm"
    target "abelcan"
    weight 3
  ]
  edge [
    source "lucaslv1"
    target "abelcan"
    weight 1
  ]
# Out:
#   File "<ipython-input-84-242842b02d6f>", line 2
#     directed 1
#              ^
# SyntaxError: invalid syntax

# %%
from statistics import mean

import seaborn as sns
import networkx as nx

import pandas as pd
import time
import datetime

# %%
data = pd.read_csv('bill/hotStuff.csv')

# %%
data2 = pd.read_excel('bill/hot100.xlsx')

# %%
data2.head(30)
# Out:
#                                                SongID  \
# 0                       AdictoTainy, Anuel AA & Ozuna
# 1   The Ones That Didn't Make It Back HomeJustin M...
# 2                   ShallowLady Gaga & Bradley Cooper
# 3                 EnemiesPost Malone Featuring DaBaby
# 4     Bacc At It AgainYella Beezy, Gucci Mane & Quavo
# 5                              The ArcherTaylor Swift
# 6                                         VIBEZDaBaby
# 7                                    When I Grow UpNF
# 8                     Hollywood's BleedingPost Malone
# 9   What Happens In A Small TownBrantley Gilbert +...
# 10                              Famous HoesNLE Choppa
# 11                        Cornelia StreetTaylor Swift
# 12                    HeatChris Brown Featuring Gunna
# 13                         Te RobareNicky Jam X Ozuna
# 14                          Yellow HeartsAnt Saunders
# 15                    Make It RightBTS Featuring Lauv
# ...

# %%
s="juao e mateus"
f="juao"
if f in s:
    print("oi")

# %%
import re

feat="Featuring"
def parse(nomes):
    new_nomes=nomes.replace("Featuring","&")
    new_nomes=new_nomes.replace(" X "," & ")
    new_nomes=new_nomes.replace(" x "," & ")
    return re.split(r'\s[,&+]\s', new_nomes)
    
print(parse("NAV Featuring Meek Mill & mia"))
# Out:
# ['NAV', 'Meek Mill', 'mia']

# %%
def createmultifeat(lista):
    final=[]
    for i in range(len(lista)):
        for j in range(i+1,len(lista)):
            final.append([lista[i],lista[j]])
    return final
print (createmultifeat(['NAV', 'Meek Mill']))
# Out:
# [['NAV', 'Meek Mill']]

# %%
lista_cantores=[]
dic_feat={}
s=0
for i in range(len(data2["Performer"])):
    lista_singers = parse(data2["Performer"][i])
    for j in lista_singers:
        if j not in lista_cantores:
            lista_cantores.append(j)
    if len(lista_singers)>1:
        
        
print(len(data2["Performer"]))
# Out:
# 28492

# %%
def ano(row):
   return int(row["WeekID"][-4:])

# %%
data['ANO'] = data.apply (lambda row: ano(row), axis=1)

# %%
dataPBANO=data[data["ANO"]>=2000]

# %%
dataPBANO[dataPBANO["Song"]=="Radioactive"].head(400)

# %%
graph [
  directed 1
  node [
    id "abelcan"
  ]
  node [
    id "andreew"
  ] 
  edge [
    source "ericfoa"
    target "abelcan"
    weight 1
  ]
  edge [
    source "joaopmjm"
    target "abelcan"
    weight 3
  ]
  edge [
    source "lucaslv1"
    target "abelcan"
    weight 1
  ]
